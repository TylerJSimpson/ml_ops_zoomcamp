# %% [markdown]
# # Duration Prediction Model

# %% [markdown]
# ## Analysis

# %%
# !python -V
# Out:
# Python 3.9.19

# %% [markdown]
# ### Import Packages

# %%
import pandas as pd
import pickle
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_squared_error

# %%
import mlflow

mlflow.set_tracking_uri("sqlite:///mlflow.db")
mlflow.set_experiment("nyc-taxi-experiment")
# Out:
# <Experiment: artifact_location='/home/tsimpson_unix/ml_ops_zoomcamp/w2_experiment_tracking/mlruns/1', creation_time=1716205390239, experiment_id='1', last_update_time=1716205390239, lifecycle_stage='active', name='nyc-taxi-experiment', tags={}>

# %% [markdown]
# ### Read Data

# %%
df = pd.read_csv('../data/green_tripdata_2021-01.csv')
# Out:
# /tmp/ipykernel_696286/1973399759.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../data/green_tripdata_2021-01.csv')

# %% [markdown]
# ### Review Data

# %%
df
# Out:
#        VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0           2.0  2021-01-01 00:15:56   2021-01-01 00:19:52                  N
# 1           2.0  2021-01-01 00:25:59   2021-01-01 00:34:44                  N
# 2           2.0  2021-01-01 00:45:57   2021-01-01 00:51:55                  N
# 3           2.0  2020-12-31 23:57:51   2021-01-01 00:04:56                  N
# 4           2.0  2021-01-01 00:16:36   2021-01-01 00:16:40                  N
# ...         ...                  ...                   ...                ...
# 76513       NaN  2021-01-15 10:35:00   2021-01-15 10:51:00                NaN
# 76514       NaN  2021-01-15 10:25:00   2021-01-15 10:34:00                NaN
# 76515       NaN  2021-01-15 10:16:00   2021-01-15 10:20:00                NaN
# 76516       NaN  2021-01-15 10:16:00   2021-01-15 10:58:00                NaN
# 76517       NaN  2021-01-15 10:24:00   2021-01-15 10:46:00                NaN
#
#        RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0             1.0            43           151              1.0           1.01
# 1             1.0           166           239              1.0           2.53
# 2             1.0            41            42              1.0           1.12
# 3             1.0           168            75              1.0           1.99
# 4             2.0           265           265              3.0           0.00
# ...           ...           ...           ...              ...            ...
# 76513         NaN             3           147              NaN           5.97
# 76514         NaN           242           213              NaN           3.83
# 76515         NaN           181           181              NaN           0.45
# 76516         NaN           244            72              NaN          22.21
# 76517         NaN           227            33              NaN           4.20
#
#        fare_amount  extra  mta_tax  tip_amount  tolls_amount  ehail_fee  \
# 0             5.50    0.5      0.5        0.00          0.00        NaN
# 1            10.00    0.5      0.5        2.81          0.00        NaN
# 2             6.00    0.5      0.5        1.00          0.00        NaN
# 3             8.00    0.5      0.5        0.00          0.00        NaN
# 4           -52.00    0.0     -0.5        0.00          0.00        NaN
# ...            ...    ...      ...         ...           ...        ...
# 76513        17.01    0.0      0.0        0.00          0.00        NaN
# 76514        27.27    0.0      0.0        2.75          0.00        NaN
# 76515        12.89    0.0      0.0        2.75          0.00        NaN
# 76516        50.67    0.0      0.0        2.75          6.12        NaN
# 76517        21.37    0.0      0.0        2.75          0.00        NaN
#
#        improvement_surcharge  total_amount  payment_type  trip_type  \
# 0                        0.3          6.80           2.0        1.0
# 1                        0.3         16.86           1.0        1.0
# 2                        0.3          8.30           1.0        1.0
# 3                        0.3          9.30           2.0        1.0
# 4                       -0.3        -52.80           3.0        1.0
# ...                      ...           ...           ...        ...
# 76513                    0.3         17.31           NaN        NaN
# 76514                    0.3         30.32           NaN        NaN
# 76515                    0.3         15.94           NaN        NaN
# 76516                    0.3         59.84           NaN        NaN
# 76517                    0.3         24.42           NaN        NaN
#
#        congestion_surcharge
# 0                      0.00
# 1                      2.75
# 2                      0.00
# 3                      0.00
# 4                      0.00
# ...                     ...
# 76513                   NaN
# 76514                   NaN
# 76515                   NaN
# 76516                   NaN
# 76517                   NaN
#
# [76518 rows x 20 columns]

# %%
df.dtypes
# Out:
# VendorID                 float64
# lpep_pickup_datetime      object
# lpep_dropoff_datetime     object
# store_and_fwd_flag        object
# RatecodeID               float64
# PULocationID               int64
# DOLocationID               int64
# passenger_count          float64
# trip_distance            float64
# fare_amount              float64
# extra                    float64
# mta_tax                  float64
# tip_amount               float64
# tolls_amount             float64
# ehail_fee                float64
# improvement_surcharge    float64
# total_amount             float64
# payment_type             float64
# trip_type                float64
# congestion_surcharge     float64
# dtype: object

# %% [markdown]
# ### EDA and feature generation

# %%
# Convert datetime columns to datetime dtype
df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)
df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)

# %%
df.dtypes
# Out:
# VendorID                        float64
# lpep_pickup_datetime     datetime64[ns]
# lpep_dropoff_datetime    datetime64[ns]
# store_and_fwd_flag               object
# RatecodeID                      float64
# PULocationID                      int64
# DOLocationID                      int64
# passenger_count                 float64
# trip_distance                   float64
# fare_amount                     float64
# extra                           float64
# mta_tax                         float64
# tip_amount                      float64
# tolls_amount                    float64
# ehail_fee                       float64
# improvement_surcharge           float64
# total_amount                    float64
# payment_type                    float64
# trip_type                       float64
# congestion_surcharge            float64
# dtype: object

# %%
# Set filter so we only have trip_type code 2 which corresponds to dispatch
# We do not want street-hail data
# df = df[df.trip_type == 2]
# We are commenting this out because it was causing weird data distributions

# %%
df
# Out:
#        VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0           2.0  2021-01-01 00:15:56   2021-01-01 00:19:52                  N
# 1           2.0  2021-01-01 00:25:59   2021-01-01 00:34:44                  N
# 2           2.0  2021-01-01 00:45:57   2021-01-01 00:51:55                  N
# 3           2.0  2020-12-31 23:57:51   2021-01-01 00:04:56                  N
# 4           2.0  2021-01-01 00:16:36   2021-01-01 00:16:40                  N
# ...         ...                  ...                   ...                ...
# 76513       NaN  2021-01-15 10:35:00   2021-01-15 10:51:00                NaN
# 76514       NaN  2021-01-15 10:25:00   2021-01-15 10:34:00                NaN
# 76515       NaN  2021-01-15 10:16:00   2021-01-15 10:20:00                NaN
# 76516       NaN  2021-01-15 10:16:00   2021-01-15 10:58:00                NaN
# 76517       NaN  2021-01-15 10:24:00   2021-01-15 10:46:00                NaN
#
#        RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0             1.0            43           151              1.0           1.01
# 1             1.0           166           239              1.0           2.53
# 2             1.0            41            42              1.0           1.12
# 3             1.0           168            75              1.0           1.99
# 4             2.0           265           265              3.0           0.00
# ...           ...           ...           ...              ...            ...
# 76513         NaN             3           147              NaN           5.97
# 76514         NaN           242           213              NaN           3.83
# 76515         NaN           181           181              NaN           0.45
# 76516         NaN           244            72              NaN          22.21
# 76517         NaN           227            33              NaN           4.20
#
#        fare_amount  extra  mta_tax  tip_amount  tolls_amount  ehail_fee  \
# 0             5.50    0.5      0.5        0.00          0.00        NaN
# 1            10.00    0.5      0.5        2.81          0.00        NaN
# 2             6.00    0.5      0.5        1.00          0.00        NaN
# 3             8.00    0.5      0.5        0.00          0.00        NaN
# 4           -52.00    0.0     -0.5        0.00          0.00        NaN
# ...            ...    ...      ...         ...           ...        ...
# 76513        17.01    0.0      0.0        0.00          0.00        NaN
# 76514        27.27    0.0      0.0        2.75          0.00        NaN
# 76515        12.89    0.0      0.0        2.75          0.00        NaN
# 76516        50.67    0.0      0.0        2.75          6.12        NaN
# 76517        21.37    0.0      0.0        2.75          0.00        NaN
#
#        improvement_surcharge  total_amount  payment_type  trip_type  \
# 0                        0.3          6.80           2.0        1.0
# 1                        0.3         16.86           1.0        1.0
# 2                        0.3          8.30           1.0        1.0
# 3                        0.3          9.30           2.0        1.0
# 4                       -0.3        -52.80           3.0        1.0
# ...                      ...           ...           ...        ...
# 76513                    0.3         17.31           NaN        NaN
# 76514                    0.3         30.32           NaN        NaN
# 76515                    0.3         15.94           NaN        NaN
# 76516                    0.3         59.84           NaN        NaN
# 76517                    0.3         24.42           NaN        NaN
#
#        congestion_surcharge
# 0                      0.00
# 1                      2.75
# 2                      0.00
# 3                      0.00
# 4                      0.00
# ...                     ...
# 76513                   NaN
# 76514                   NaN
# 76515                   NaN
# 76516                   NaN
# 76517                   NaN
#
# [76518 rows x 20 columns]

# %%
# Calculate duration
df['duration'] = (df.lpep_dropoff_datetime - df.lpep_pickup_datetime)

# %%
df
# Out:
#        VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0           2.0  2021-01-01 00:15:56   2021-01-01 00:19:52                  N
# 1           2.0  2021-01-01 00:25:59   2021-01-01 00:34:44                  N
# 2           2.0  2021-01-01 00:45:57   2021-01-01 00:51:55                  N
# 3           2.0  2020-12-31 23:57:51   2021-01-01 00:04:56                  N
# 4           2.0  2021-01-01 00:16:36   2021-01-01 00:16:40                  N
# ...         ...                  ...                   ...                ...
# 76513       NaN  2021-01-15 10:35:00   2021-01-15 10:51:00                NaN
# 76514       NaN  2021-01-15 10:25:00   2021-01-15 10:34:00                NaN
# 76515       NaN  2021-01-15 10:16:00   2021-01-15 10:20:00                NaN
# 76516       NaN  2021-01-15 10:16:00   2021-01-15 10:58:00                NaN
# 76517       NaN  2021-01-15 10:24:00   2021-01-15 10:46:00                NaN
#
#        RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0             1.0            43           151              1.0           1.01
# 1             1.0           166           239              1.0           2.53
# 2             1.0            41            42              1.0           1.12
# 3             1.0           168            75              1.0           1.99
# 4             2.0           265           265              3.0           0.00
# ...           ...           ...           ...              ...            ...
# 76513         NaN             3           147              NaN           5.97
# 76514         NaN           242           213              NaN           3.83
# 76515         NaN           181           181              NaN           0.45
# 76516         NaN           244            72              NaN          22.21
# 76517         NaN           227            33              NaN           4.20
#
#        fare_amount  ...  mta_tax  tip_amount  tolls_amount  ehail_fee  \
# 0             5.50  ...      0.5        0.00          0.00        NaN
# 1            10.00  ...      0.5        2.81          0.00        NaN
# 2             6.00  ...      0.5        1.00          0.00        NaN
# 3             8.00  ...      0.5        0.00          0.00        NaN
# 4           -52.00  ...     -0.5        0.00          0.00        NaN
# ...            ...  ...      ...         ...           ...        ...
# 76513        17.01  ...      0.0        0.00          0.00        NaN
# 76514        27.27  ...      0.0        2.75          0.00        NaN
# 76515        12.89  ...      0.0        2.75          0.00        NaN
# 76516        50.67  ...      0.0        2.75          6.12        NaN
# 76517        21.37  ...      0.0        2.75          0.00        NaN
#
#        improvement_surcharge  total_amount  payment_type  trip_type  \
# 0                        0.3          6.80           2.0        1.0
# 1                        0.3         16.86           1.0        1.0
# 2                        0.3          8.30           1.0        1.0
# 3                        0.3          9.30           2.0        1.0
# 4                       -0.3        -52.80           3.0        1.0
# ...                      ...           ...           ...        ...
# 76513                    0.3         17.31           NaN        NaN
# 76514                    0.3         30.32           NaN        NaN
# 76515                    0.3         15.94           NaN        NaN
# 76516                    0.3         59.84           NaN        NaN
# 76517                    0.3         24.42           NaN        NaN
#
#        congestion_surcharge        duration
# 0                      0.00 0 days 00:03:56
# 1                      2.75 0 days 00:08:45
# 2                      0.00 0 days 00:05:58
# 3                      0.00 0 days 00:07:05
# 4                      0.00 0 days 00:00:04
# ...                     ...             ...
# 76513                   NaN 0 days 00:16:00
# 76514                   NaN 0 days 00:09:00
# 76515                   NaN 0 days 00:04:00
# 76516                   NaN 0 days 00:42:00
# 76517                   NaN 0 days 00:22:00
#
# [76518 rows x 21 columns]

# %%
# Duration is not very useful in this form, conver to minutes
df.duration = df.duration.apply(lambda td: td.total_seconds() / 60)

# %%
df
# Out:
#        VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0           2.0  2021-01-01 00:15:56   2021-01-01 00:19:52                  N
# 1           2.0  2021-01-01 00:25:59   2021-01-01 00:34:44                  N
# 2           2.0  2021-01-01 00:45:57   2021-01-01 00:51:55                  N
# 3           2.0  2020-12-31 23:57:51   2021-01-01 00:04:56                  N
# 4           2.0  2021-01-01 00:16:36   2021-01-01 00:16:40                  N
# ...         ...                  ...                   ...                ...
# 76513       NaN  2021-01-15 10:35:00   2021-01-15 10:51:00                NaN
# 76514       NaN  2021-01-15 10:25:00   2021-01-15 10:34:00                NaN
# 76515       NaN  2021-01-15 10:16:00   2021-01-15 10:20:00                NaN
# 76516       NaN  2021-01-15 10:16:00   2021-01-15 10:58:00                NaN
# 76517       NaN  2021-01-15 10:24:00   2021-01-15 10:46:00                NaN
#
#        RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0             1.0            43           151              1.0           1.01
# 1             1.0           166           239              1.0           2.53
# 2             1.0            41            42              1.0           1.12
# 3             1.0           168            75              1.0           1.99
# 4             2.0           265           265              3.0           0.00
# ...           ...           ...           ...              ...            ...
# 76513         NaN             3           147              NaN           5.97
# 76514         NaN           242           213              NaN           3.83
# 76515         NaN           181           181              NaN           0.45
# 76516         NaN           244            72              NaN          22.21
# 76517         NaN           227            33              NaN           4.20
#
#        fare_amount  ...  mta_tax  tip_amount  tolls_amount  ehail_fee  \
# 0             5.50  ...      0.5        0.00          0.00        NaN
# 1            10.00  ...      0.5        2.81          0.00        NaN
# 2             6.00  ...      0.5        1.00          0.00        NaN
# 3             8.00  ...      0.5        0.00          0.00        NaN
# 4           -52.00  ...     -0.5        0.00          0.00        NaN
# ...            ...  ...      ...         ...           ...        ...
# 76513        17.01  ...      0.0        0.00          0.00        NaN
# 76514        27.27  ...      0.0        2.75          0.00        NaN
# 76515        12.89  ...      0.0        2.75          0.00        NaN
# 76516        50.67  ...      0.0        2.75          6.12        NaN
# 76517        21.37  ...      0.0        2.75          0.00        NaN
#
#        improvement_surcharge  total_amount  payment_type  trip_type  \
# 0                        0.3          6.80           2.0        1.0
# 1                        0.3         16.86           1.0        1.0
# 2                        0.3          8.30           1.0        1.0
# 3                        0.3          9.30           2.0        1.0
# 4                       -0.3        -52.80           3.0        1.0
# ...                      ...           ...           ...        ...
# 76513                    0.3         17.31           NaN        NaN
# 76514                    0.3         30.32           NaN        NaN
# 76515                    0.3         15.94           NaN        NaN
# 76516                    0.3         59.84           NaN        NaN
# 76517                    0.3         24.42           NaN        NaN
#
#        congestion_surcharge   duration
# 0                      0.00   3.933333
# 1                      2.75   8.750000
# 2                      0.00   5.966667
# 3                      0.00   7.083333
# 4                      0.00   0.066667
# ...                     ...        ...
# 76513                   NaN  16.000000
# 76514                   NaN   9.000000
# 76515                   NaN   4.000000
# 76516                   NaN  42.000000
# 76517                   NaN  22.000000
#
# [76518 rows x 21 columns]

# %%
df.duration.describe()
# Out:
# count    76518.000000
# mean        19.927896
# std         59.338594
# min          0.000000
# 25%          8.000000
# 50%         13.883333
# 75%         23.000000
# max       1439.600000
# Name: duration, dtype: float64

# %%
# There were many odd low durations so let's take a look at the percentiles
df.duration.describe(percentiles=[0.95, 0.98, 0.99])
# Out:
# count    76518.000000
# mean        19.927896
# std         59.338594
# min          0.000000
# 50%         13.883333
# 95%         44.000000
# 98%         56.000000
# 99%         67.158167
# max       1439.600000
# Name: duration, dtype: float64

# %%
((df.duration >= 1) & (df. duration <= 50)).mean()
# Out:
# 0.9508873729057216

# %%
# Only 50% of trip durations are between 1 and 50 minutes which seems strange
# Because of this we commented out the filtering of only type 2 rides which made this number look much more accurate

# %%
df = df[(df.duration >= 1) & (df. duration <= 60)]

# %%
df
# Out:
#        VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0           2.0  2021-01-01 00:15:56   2021-01-01 00:19:52                  N
# 1           2.0  2021-01-01 00:25:59   2021-01-01 00:34:44                  N
# 2           2.0  2021-01-01 00:45:57   2021-01-01 00:51:55                  N
# 3           2.0  2020-12-31 23:57:51   2021-01-01 00:04:56                  N
# 7           2.0  2021-01-01 00:26:31   2021-01-01 00:28:50                  N
# ...         ...                  ...                   ...                ...
# 76513       NaN  2021-01-15 10:35:00   2021-01-15 10:51:00                NaN
# 76514       NaN  2021-01-15 10:25:00   2021-01-15 10:34:00                NaN
# 76515       NaN  2021-01-15 10:16:00   2021-01-15 10:20:00                NaN
# 76516       NaN  2021-01-15 10:16:00   2021-01-15 10:58:00                NaN
# 76517       NaN  2021-01-15 10:24:00   2021-01-15 10:46:00                NaN
#
#        RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0             1.0            43           151              1.0           1.01
# 1             1.0           166           239              1.0           2.53
# 2             1.0            41            42              1.0           1.12
# 3             1.0           168            75              1.0           1.99
# 7             1.0            75            75              6.0           0.45
# ...           ...           ...           ...              ...            ...
# 76513         NaN             3           147              NaN           5.97
# 76514         NaN           242           213              NaN           3.83
# 76515         NaN           181           181              NaN           0.45
# 76516         NaN           244            72              NaN          22.21
# 76517         NaN           227            33              NaN           4.20
#
#        fare_amount  ...  mta_tax  tip_amount  tolls_amount  ehail_fee  \
# 0             5.50  ...      0.5        0.00          0.00        NaN
# 1            10.00  ...      0.5        2.81          0.00        NaN
# 2             6.00  ...      0.5        1.00          0.00        NaN
# 3             8.00  ...      0.5        0.00          0.00        NaN
# 7             3.50  ...      0.5        0.96          0.00        NaN
# ...            ...  ...      ...         ...           ...        ...
# 76513        17.01  ...      0.0        0.00          0.00        NaN
# 76514        27.27  ...      0.0        2.75          0.00        NaN
# 76515        12.89  ...      0.0        2.75          0.00        NaN
# 76516        50.67  ...      0.0        2.75          6.12        NaN
# 76517        21.37  ...      0.0        2.75          0.00        NaN
#
#        improvement_surcharge  total_amount  payment_type  trip_type  \
# 0                        0.3          6.80           2.0        1.0
# 1                        0.3         16.86           1.0        1.0
# 2                        0.3          8.30           1.0        1.0
# 3                        0.3          9.30           2.0        1.0
# 7                        0.3          5.76           1.0        1.0
# ...                      ...           ...           ...        ...
# 76513                    0.3         17.31           NaN        NaN
# 76514                    0.3         30.32           NaN        NaN
# 76515                    0.3         15.94           NaN        NaN
# 76516                    0.3         59.84           NaN        NaN
# 76517                    0.3         24.42           NaN        NaN
#
#        congestion_surcharge   duration
# 0                      0.00   3.933333
# 1                      2.75   8.750000
# 2                      0.00   5.966667
# 3                      0.00   7.083333
# 7                      0.00   2.316667
# ...                     ...        ...
# 76513                   NaN  16.000000
# 76514                   NaN   9.000000
# 76515                   NaN   4.000000
# 76516                   NaN  42.000000
# 76517                   NaN  22.000000
#
# [73908 rows x 21 columns]

# %%
# Let's take a look at categorical variables and split out the numericals

# %%
categorical = ['PULocationID', 'DOLocationID']
numerical = ['trip_distance']

# %%
# Check dtype of categoricals
df[categorical].dtypes
# Out:
# PULocationID    int64
# DOLocationID    int64
# dtype: object

# %%
# We can convert these via encoding so they can be used in a model
df[categorical] = df[categorical].astype(str)
# Out:
# /tmp/ipykernel_696286/2496045046.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[categorical] = df[categorical].astype(str)

# %%
df[categorical].dtypes
# Out:
# PULocationID    object
# DOLocationID    object
# dtype: object

# %% [markdown]
# ### Model creation

# %%
train_dicts = df[categorical + numerical].to_dict(orient='records')

# %%
# This vectorizer will transform the categorical features into a vector so categoricals can be used in the model
dv = DictVectorizer()
X_train = dv.fit_transform(train_dicts)

# %%
X_train
# Out:
# <73908x507 sparse matrix of type '<class 'numpy.float64'>'
# 	with 221724 stored elements in Compressed Sparse Row format>

# %%
dv.feature_names_
# Out:
# ['DOLocationID=1',
#  'DOLocationID=10',
#  'DOLocationID=100',
#  'DOLocationID=101',
#  'DOLocationID=102',
#  'DOLocationID=106',
#  'DOLocationID=107',
#  'DOLocationID=108',
#  'DOLocationID=109',
#  'DOLocationID=11',
#  'DOLocationID=111',
#  'DOLocationID=112',
#  'DOLocationID=113',
#  'DOLocationID=114',
#  'DOLocationID=115',
#  'DOLocationID=116',
#  'DOLocationID=117',
#  'DOLocationID=118',
#  'DOLocationID=119',
#  'DOLocationID=12',
#  'DOLocationID=120',
#  'DOLocationID=121',
#  'DOLocationID=122',
#  'DOLocationID=123',
#  'DOLocationID=124',
#  'DOLocationID=125',
#  'DOLocationID=126',
#  'DOLocationID=127',
#  'DOLocationID=128',
#  'DOLocationID=129',
#  'DOLocationID=13',
#  'DOLocationID=130',
#  'DOLocationID=131',
#  'DOLocationID=132',
#  'DOLocationID=133',
#  'DOLocationID=134',
#  'DOLocationID=135',
#  'DOLocationID=136',
#  'DOLocationID=137',
#  'DOLocationID=138',
#  'DOLocationID=139',
#  'DOLocationID=14',
#  'DOLocationID=140',
#  'DOLocationID=141',
#  'DOLocationID=142',
#  'DOLocationID=143',
#  'DOLocationID=144',
#  'DOLocationID=145',
#  'DOLocationID=146',
#  'DOLocationID=147',
#  'DOLocationID=148',
#  'DOLocationID=149',
#  'DOLocationID=15',
#  'DOLocationID=150',
#  'DOLocationID=151',
#  'DOLocationID=152',
#  'DOLocationID=153',
#  'DOLocationID=154',
#  'DOLocationID=155',
#  'DOLocationID=156',
#  'DOLocationID=157',
#  'DOLocationID=158',
#  'DOLocationID=159',
#  'DOLocationID=16',
#  'DOLocationID=160',
#  'DOLocationID=161',
#  'DOLocationID=162',
#  'DOLocationID=163',
#  'DOLocationID=164',
#  'DOLocationID=165',
#  'DOLocationID=166',
#  'DOLocationID=167',
#  'DOLocationID=168',
#  'DOLocationID=169',
#  'DOLocationID=17',
#  'DOLocationID=170',
#  'DOLocationID=171',
#  'DOLocationID=172',
#  'DOLocationID=173',
#  'DOLocationID=174',
#  'DOLocationID=175',
#  'DOLocationID=177',
#  'DOLocationID=178',
#  'DOLocationID=179',
#  'DOLocationID=18',
#  'DOLocationID=180',
#  'DOLocationID=181',
#  'DOLocationID=182',
#  'DOLocationID=183',
#  'DOLocationID=184',
#  'DOLocationID=185',
#  'DOLocationID=186',
#  'DOLocationID=187',
#  'DOLocationID=188',
#  'DOLocationID=189',
#  'DOLocationID=19',
#  'DOLocationID=190',
#  'DOLocationID=191',
#  'DOLocationID=192',
#  'DOLocationID=193',
#  'DOLocationID=194',
#  'DOLocationID=195',
#  'DOLocationID=196',
#  'DOLocationID=197',
#  'DOLocationID=198',
#  'DOLocationID=2',
#  'DOLocationID=20',
#  'DOLocationID=200',
#  'DOLocationID=201',
#  'DOLocationID=202',
#  'DOLocationID=203',
#  'DOLocationID=205',
#  'DOLocationID=206',
#  'DOLocationID=207',
#  'DOLocationID=208',
#  'DOLocationID=209',
#  'DOLocationID=21',
#  'DOLocationID=210',
#  'DOLocationID=211',
#  'DOLocationID=212',
#  'DOLocationID=213',
#  'DOLocationID=214',
#  'DOLocationID=215',
#  'DOLocationID=216',
#  'DOLocationID=217',
#  'DOLocationID=218',
#  'DOLocationID=219',
#  'DOLocationID=22',
#  'DOLocationID=220',
#  'DOLocationID=221',
#  'DOLocationID=222',
#  'DOLocationID=223',
#  'DOLocationID=224',
#  'DOLocationID=225',
#  'DOLocationID=226',
#  'DOLocationID=227',
#  'DOLocationID=228',
#  'DOLocationID=229',
#  'DOLocationID=23',
#  'DOLocationID=230',
#  'DOLocationID=231',
#  'DOLocationID=232',
#  'DOLocationID=233',
#  'DOLocationID=234',
#  'DOLocationID=235',
#  'DOLocationID=236',
#  'DOLocationID=237',
#  'DOLocationID=238',
#  'DOLocationID=239',
#  'DOLocationID=24',
#  'DOLocationID=240',
#  'DOLocationID=241',
#  'DOLocationID=242',
#  'DOLocationID=243',
#  'DOLocationID=244',
#  'DOLocationID=245',
#  'DOLocationID=246',
#  'DOLocationID=247',
#  'DOLocationID=248',
#  'DOLocationID=249',
#  'DOLocationID=25',
#  'DOLocationID=250',
#  'DOLocationID=251',
#  'DOLocationID=252',
#  'DOLocationID=253',
#  'DOLocationID=254',
#  'DOLocationID=255',
#  'DOLocationID=256',
#  'DOLocationID=257',
#  'DOLocationID=258',
#  'DOLocationID=259',
#  'DOLocationID=26',
#  'DOLocationID=260',
#  'DOLocationID=261',
#  'DOLocationID=262',
#  'DOLocationID=263',
#  'DOLocationID=264',
#  'DOLocationID=265',
#  'DOLocationID=27',
#  'DOLocationID=28',
#  'DOLocationID=29',
#  'DOLocationID=3',
#  'DOLocationID=30',
#  'DOLocationID=31',
#  'DOLocationID=32',
#  'DOLocationID=33',
#  'DOLocationID=34',
#  'DOLocationID=35',
#  'DOLocationID=36',
#  'DOLocationID=37',
#  'DOLocationID=38',
#  'DOLocationID=39',
#  'DOLocationID=4',
#  'DOLocationID=40',
#  'DOLocationID=41',
#  'DOLocationID=42',
#  'DOLocationID=43',
#  'DOLocationID=44',
#  'DOLocationID=45',
#  'DOLocationID=46',
#  'DOLocationID=47',
#  'DOLocationID=48',
#  'DOLocationID=49',
#  'DOLocationID=50',
#  'DOLocationID=51',
#  'DOLocationID=52',
#  'DOLocationID=53',
#  'DOLocationID=54',
#  'DOLocationID=55',
#  'DOLocationID=56',
#  'DOLocationID=57',
#  'DOLocationID=58',
#  'DOLocationID=59',
#  'DOLocationID=6',
#  'DOLocationID=60',
#  'DOLocationID=61',
#  'DOLocationID=62',
#  'DOLocationID=63',
#  'DOLocationID=64',
#  'DOLocationID=65',
#  'DOLocationID=66',
#  'DOLocationID=67',
#  'DOLocationID=68',
#  'DOLocationID=69',
#  'DOLocationID=7',
#  'DOLocationID=70',
#  'DOLocationID=71',
#  'DOLocationID=72',
#  'DOLocationID=73',
#  'DOLocationID=74',
#  'DOLocationID=75',
#  'DOLocationID=76',
#  'DOLocationID=77',
#  'DOLocationID=78',
#  'DOLocationID=79',
#  'DOLocationID=8',
#  'DOLocationID=80',
#  'DOLocationID=81',
#  'DOLocationID=82',
#  'DOLocationID=83',
#  'DOLocationID=84',
#  'DOLocationID=85',
#  'DOLocationID=86',
#  'DOLocationID=87',
#  'DOLocationID=88',
#  'DOLocationID=89',
#  'DOLocationID=9',
#  'DOLocationID=90',
#  'DOLocationID=91',
#  'DOLocationID=92',
#  'DOLocationID=93',
#  'DOLocationID=94',
#  'DOLocationID=95',
#  'DOLocationID=96',
#  'DOLocationID=97',
#  'DOLocationID=98',
#  'PULocationID=10',
#  'PULocationID=100',
#  'PULocationID=101',
#  'PULocationID=102',
#  'PULocationID=106',
#  'PULocationID=107',
#  'PULocationID=108',
#  'PULocationID=11',
#  'PULocationID=112',
#  'PULocationID=113',
#  'PULocationID=114',
#  'PULocationID=115',
#  'PULocationID=116',
#  'PULocationID=117',
#  'PULocationID=118',
#  'PULocationID=119',
#  'PULocationID=12',
#  'PULocationID=120',
#  'PULocationID=121',
#  'PULocationID=122',
#  'PULocationID=123',
#  'PULocationID=124',
#  'PULocationID=125',
#  'PULocationID=126',
#  'PULocationID=127',
#  'PULocationID=128',
#  'PULocationID=129',
#  'PULocationID=13',
#  'PULocationID=130',
#  'PULocationID=131',
#  'PULocationID=132',
#  'PULocationID=133',
#  'PULocationID=134',
#  'PULocationID=135',
#  'PULocationID=136',
#  'PULocationID=137',
#  'PULocationID=138',
#  'PULocationID=139',
#  'PULocationID=14',
#  'PULocationID=140',
#  'PULocationID=141',
#  'PULocationID=142',
#  'PULocationID=143',
#  'PULocationID=144',
#  'PULocationID=145',
#  'PULocationID=146',
#  'PULocationID=147',
#  'PULocationID=148',
#  'PULocationID=149',
#  'PULocationID=15',
#  'PULocationID=150',
#  'PULocationID=151',
#  'PULocationID=152',
#  'PULocationID=153',
#  'PULocationID=154',
#  'PULocationID=155',
#  'PULocationID=156',
#  'PULocationID=157',
#  'PULocationID=158',
#  'PULocationID=159',
#  'PULocationID=16',
#  'PULocationID=160',
#  'PULocationID=161',
#  'PULocationID=162',
#  'PULocationID=163',
#  'PULocationID=164',
#  'PULocationID=165',
#  'PULocationID=166',
#  'PULocationID=167',
#  'PULocationID=168',
#  'PULocationID=169',
#  'PULocationID=17',
#  'PULocationID=170',
#  'PULocationID=171',
#  'PULocationID=172',
#  'PULocationID=173',
#  'PULocationID=174',
#  'PULocationID=175',
#  'PULocationID=176',
#  'PULocationID=177',
#  'PULocationID=178',
#  'PULocationID=179',
#  'PULocationID=18',
#  'PULocationID=180',
#  'PULocationID=181',
#  'PULocationID=182',
#  'PULocationID=183',
#  'PULocationID=184',
#  'PULocationID=185',
#  'PULocationID=186',
#  'PULocationID=187',
#  'PULocationID=188',
#  'PULocationID=189',
#  'PULocationID=19',
#  'PULocationID=190',
#  'PULocationID=191',
#  'PULocationID=192',
#  'PULocationID=193',
#  'PULocationID=194',
#  'PULocationID=195',
#  'PULocationID=196',
#  'PULocationID=197',
#  'PULocationID=198',
#  'PULocationID=20',
#  'PULocationID=200',
#  'PULocationID=201',
#  'PULocationID=202',
#  'PULocationID=203',
#  'PULocationID=205',
#  'PULocationID=206',
#  'PULocationID=207',
#  'PULocationID=208',
#  'PULocationID=209',
#  'PULocationID=21',
#  'PULocationID=210',
#  'PULocationID=211',
#  'PULocationID=212',
#  'PULocationID=213',
#  'PULocationID=214',
#  'PULocationID=215',
#  'PULocationID=216',
#  'PULocationID=217',
#  'PULocationID=218',
#  'PULocationID=219',
#  'PULocationID=22',
#  'PULocationID=220',
#  'PULocationID=221',
#  'PULocationID=222',
#  'PULocationID=223',
#  'PULocationID=224',
#  'PULocationID=225',
#  'PULocationID=226',
#  'PULocationID=227',
#  'PULocationID=228',
#  'PULocationID=229',
#  'PULocationID=23',
#  'PULocationID=230',
#  'PULocationID=231',
#  'PULocationID=232',
#  'PULocationID=233',
#  'PULocationID=234',
#  'PULocationID=235',
#  'PULocationID=236',
#  'PULocationID=237',
#  'PULocationID=238',
#  'PULocationID=239',
#  'PULocationID=24',
#  'PULocationID=240',
#  'PULocationID=241',
#  'PULocationID=242',
#  'PULocationID=243',
#  'PULocationID=244',
#  'PULocationID=245',
#  'PULocationID=246',
#  'PULocationID=247',
#  'PULocationID=248',
#  'PULocationID=249',
#  'PULocationID=25',
#  'PULocationID=250',
#  'PULocationID=252',
#  'PULocationID=253',
#  'PULocationID=254',
#  'PULocationID=255',
#  'PULocationID=256',
#  'PULocationID=257',
#  'PULocationID=258',
#  'PULocationID=259',
#  'PULocationID=26',
#  'PULocationID=260',
#  'PULocationID=261',
#  'PULocationID=262',
#  'PULocationID=263',
#  'PULocationID=264',
#  'PULocationID=265',
#  'PULocationID=27',
#  'PULocationID=28',
#  'PULocationID=29',
#  'PULocationID=3',
#  'PULocationID=31',
#  'PULocationID=32',
#  'PULocationID=33',
#  'PULocationID=34',
#  'PULocationID=35',
#  'PULocationID=36',
#  'PULocationID=37',
#  'PULocationID=38',
#  'PULocationID=39',
#  'PULocationID=4',
#  'PULocationID=40',
#  'PULocationID=41',
#  'PULocationID=42',
#  'PULocationID=43',
#  'PULocationID=44',
#  'PULocationID=45',
#  'PULocationID=46',
#  'PULocationID=47',
#  'PULocationID=48',
#  'PULocationID=49',
#  'PULocationID=50',
#  'PULocationID=51',
#  'PULocationID=52',
#  'PULocationID=53',
#  'PULocationID=54',
#  'PULocationID=55',
#  'PULocationID=56',
#  'PULocationID=57',
#  'PULocationID=58',
#  'PULocationID=59',
#  'PULocationID=60',
#  'PULocationID=61',
#  'PULocationID=62',
#  'PULocationID=63',
#  'PULocationID=64',
#  'PULocationID=65',
#  'PULocationID=66',
#  'PULocationID=67',
#  'PULocationID=68',
#  'PULocationID=69',
#  'PULocationID=7',
#  'PULocationID=70',
#  'PULocationID=71',
#  'PULocationID=72',
#  'PULocationID=73',
#  'PULocationID=74',
#  'PULocationID=75',
#  'PULocationID=76',
#  'PULocationID=77',
#  'PULocationID=78',
#  'PULocationID=79',
#  'PULocationID=8',
#  'PULocationID=80',
#  'PULocationID=81',
#  'PULocationID=82',
#  'PULocationID=83',
#  'PULocationID=84',
#  'PULocationID=85',
#  'PULocationID=86',
#  'PULocationID=87',
#  'PULocationID=88',
#  'PULocationID=89',
#  'PULocationID=9',
#  'PULocationID=90',
#  'PULocationID=91',
#  'PULocationID=92',
#  'PULocationID=93',
#  'PULocationID=94',
#  'PULocationID=95',
#  'PULocationID=96',
#  'PULocationID=97',
#  'PULocationID=98',
#  'trip_distance']

# %%
target = 'duration'
y_train = df[target].values

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_train)

# %%
sns.distplot(y_pred, label='prediction')
sns.distplot(y_train, label='actual')

plt.xlim(-5, 70)

plt.legend()

plt.show()
# Out:
# /tmp/ipykernel_696286/3831492026.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(y_pred, label='prediction')
# /tmp/ipykernel_696286/3831492026.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(y_train, label='actual')

# %%
mean_squared_error(y_train, y_pred, squared=False)
# Out:
# /home/tsimpson_unix/anaconda3/envs/ml-ops-zoomcamp-01/lib/python3.9/site-packages/sklearn/metrics/_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# 9.838799799829497

# %%
# On average our model is wrong by about 10 minutes which isn't good but it's a start

# %% [markdown]
# ### Model improvement

# %%
# First lets combine all of our cleaning and feature generation into a pre-processing function we can execute

def read_dataframe(filename):
    df = pd.read_csv(filename)

    df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)
    df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)

    df['duration'] = (df.lpep_dropoff_datetime - df.lpep_pickup_datetime)
    df.duration = df.duration.apply(lambda td: td.total_seconds() / 60)
    df = df[(df.duration >= 1) & (df. duration <= 60)]

    categorical = ['PULocationID', 'DOLocationID']
    #numerical = ['trip_distance'] #numerical not needed in this function since we don't do preprocessing on it

    df[categorical] = df[categorical].astype(str)
    
    return df

# %%
# Now we can easily create train and validation sets since pre-processing has been condensed into a function
df_train = read_dataframe('../data/green_tripdata_2021-01.csv')
df_val = read_dataframe('../data/green_tripdata_2021-02.csv')
# Out:
# /tmp/ipykernel_696286/3151220129.py:4: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filename)

# %%
len(df_train), len(df_val)
# Out:
# (73908, 61921)

# %%
df_train['PU_DO'] = df_train['PULocationID'] + '_' + df_train['DOLocationID']
df_val['PU_DO'] = df_val['PULocationID'] + '_' + df_val['DOLocationID']

# %%
df_val
# Out:
#        VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0           2.0  2021-02-01 00:34:03   2021-02-01 00:51:58                  N
# 1           2.0  2021-02-01 00:04:00   2021-02-01 00:10:30                  N
# 2           2.0  2021-02-01 00:18:51   2021-02-01 00:34:06                  N
# 3           2.0  2021-02-01 00:53:27   2021-02-01 01:11:41                  N
# 4           2.0  2021-02-01 00:57:46   2021-02-01 01:06:44                  N
# ...         ...                  ...                   ...                ...
# 64567       NaN  2021-02-26 08:46:00   2021-02-26 08:59:00                NaN
# 64568       NaN  2021-02-26 08:56:00   2021-02-26 09:10:00                NaN
# 64569       NaN  2021-02-26 08:46:00   2021-02-26 09:07:00                NaN
# 64570       NaN  2021-02-26 08:17:00   2021-02-26 08:51:00                NaN
# 64571       NaN  2021-02-26 08:12:00   2021-02-26 08:29:00                NaN
#
#        RatecodeID PULocationID DOLocationID  passenger_count  trip_distance  \
# 0             1.0          130          205              5.0           3.66
# 1             1.0          152          244              1.0           1.10
# 2             1.0          152           48              1.0           4.93
# 3             1.0          152          241              1.0           6.70
# 4             1.0           75           42              1.0           1.89
# ...           ...          ...          ...              ...            ...
# 64567         NaN          167          247              NaN           1.47
# 64568         NaN           89          123              NaN           2.87
# 64569         NaN          127          166              NaN           4.74
# 64570         NaN           42          137              NaN           7.63
# 64571         NaN           74          236              NaN           1.69
#
#        fare_amount  ...  tip_amount  tolls_amount  ehail_fee  \
# 0            14.00  ...       10.00           0.0        NaN
# 1             6.50  ...        0.00           0.0        NaN
# 2            16.50  ...        0.00           0.0        NaN
# 3            21.00  ...        0.00           0.0        NaN
# 4             8.50  ...        2.45           0.0        NaN
# ...            ...  ...         ...           ...        ...
# 64567        14.55  ...        0.00           0.0        NaN
# 64568        20.22  ...        0.00           0.0        NaN
# 64569        24.94  ...        0.00           0.0        NaN
# 64570        41.81  ...        0.00           0.0        NaN
# 64571        16.58  ...        0.00           0.0        NaN
#
#        improvement_surcharge  total_amount  payment_type  trip_type  \
# 0                        0.3         25.30           1.0        1.0
# 1                        0.3          7.80           2.0        1.0
# 2                        0.3         20.55           2.0        1.0
# 3                        0.3         22.30           2.0        1.0
# 4                        0.3         12.25           1.0        1.0
# ...                      ...           ...           ...        ...
# 64567                    0.3         17.60           NaN        NaN
# 64568                    0.3         23.27           NaN        NaN
# 64569                    0.3         30.74           NaN        NaN
# 64570                    0.3         44.86           NaN        NaN
# 64571                    0.3         19.63           NaN        NaN
#
#        congestion_surcharge   duration    PU_DO
# 0                      0.00  17.916667  130_205
# 1                      0.00   6.500000  152_244
# 2                      2.75  15.250000   152_48
# 3                      0.00  18.233333  152_241
# 4                      0.00   8.966667    75_42
# ...                     ...        ...      ...
# 64567                   NaN  13.000000  167_247
# 64568                   NaN  14.000000   89_123
# 64569                   NaN  21.000000  127_166
# 64570                   NaN  34.000000   42_137
# 64571                   NaN  17.000000   74_236
#
# [61921 rows x 22 columns]

# %%
# Now let's combine all the post-processing and include the steps for our validation set

categorical = ['PU_DO'] #'PULocationID', 'DOLocationID']
numerical = ['trip_distance']

dv = DictVectorizer()

train_dicts = df_train[categorical + numerical].to_dict(orient='records')
X_train = dv.fit_transform(train_dicts)

val_dicts = df_val[categorical + numerical].to_dict(orient='records')
X_val = dv.transform(val_dicts) # Note we just transform not fit_transform here we don't want learning to take place

# %%
target = 'duration'
y_train = df_train[target].values
y_val = df_val[target].values

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)

y_pred = lr.predict(X_val)

mean_squared_error(y_val, y_pred, squared=False)
# Out:
# /home/tsimpson_unix/anaconda3/envs/ml-ops-zoomcamp-01/lib/python3.9/site-packages/sklearn/metrics/_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# 7.7587152053176585

# %%
# Now that we have a baseline let's try other models such as Lasso
# Lasso introduces some regularization

lr = Lasso()
lr.fit(X_train, y_train)

y_pred = lr.predict(X_val)

mean_squared_error(y_val, y_pred, squared=False)
# Out:
# /home/tsimpson_unix/anaconda3/envs/ml-ops-zoomcamp-01/lib/python3.9/site-packages/sklearn/metrics/_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# 12.212583224318816

# %%
"""# Worse with default but we can change parameters

lr = Lasso(alpha = 0.005) # Note I tested multiple alpha values
lr.fit(X_train, y_train)

y_pred = lr.predict(X_val)

mean_squared_error(y_val, y_pred, squared=False)"""
# Out:
# /home/tsimpson_unix/anaconda3/envs/ml-ops-zoomcamp-01/lib/python3.9/site-packages/sklearn/metrics/_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# 10.696342127127648

# %%
# Let's try another model Ridge regression another form of regulrizated linear regression
with mlflow.start_run():

    # mlflow.set_tag("tag1", "tag2") # You can use this to add developer name and other useful tags
    # Here is an example of parameter logging where we do basic data "versioning"
    mlflow.log_param("train-data-path", "../data/green_tripdata_2021-01.csv")
    mlflow.log_param("val-data-path", "../data/green_tripdata_2021-02.csv")

    alpha = 0.01
    mlflow.log_param("alpha", alpha) # Keep track of each alpha we pass

    lr = Ridge(alpha) # Note I tested multiple alpha values
    lr.fit(X_train, y_train)

    y_pred = lr.predict(X_val)
    rmse = mean_squared_error(y_val, y_pred, squared=False)
    mlflow.log_metric("rmse", rmse)
# Out:
# /home/tsimpson_unix/anaconda3/envs/ml-ops-zoomcamp-01/lib/python3.9/site-packages/sklearn/metrics/_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %%
# We are going to add to and manipulate features above which won't be evident scrolling through the notebook so I will note it here
# 1. Adding PU_DO feature to combine pickup and dropoff locations and removed them individually
# This improved the model accuracy from ~10% to ~7%

# %%
# Experiment tracking demo

import xgboost as xgb

"""
fmin - finds minimum of output
tpe - algorithm to control logic
hp - library that contains methods to define ranges for each hyperparameter
STATUS_OK - at end of each run tells the system it is ok
Trials - keeps track of information from each run
scope - determines range of type int
"""
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from hyperopt.pyll import scope

# First we must set the train and validation data to the correct format for xgboost
train = xgb.DMatrix(X_train, label=y_train)
valid = xgb.DMatrix(X_val, label=y_val)

def objective(params):
    with mlflow.start_run():
        mlflow.set_tag("model", "xgboost")
        mlflow.log_params(params)
        booster = xgb.train(
            params=params, # Specify parameters which are input variables in this case
            dtrain=train, # Specify training dataset
            num_boost_round=1000, # Set maximum iterations
            evals=[(valid, "validation")], # Specify evaluation dataset
            early_stopping_rounds=50 # If 50 iterations go without improvement early stop is done
        )

        y_pred=booster.predict(valid) # Once model trained, make predictions on validation set
        rmse=mean_squared_error(y_val, y_pred, squared=False) # RMSE to determine performance
        mlflow.log_metric("rmse", rmse)

    return {'loss': rmse, 'status': STATUS_OK}
    
search_space = {
    # Controls depth of trees (converts float to int inside)
    'max_depth': scope.int(hp.quniform('max_depth',4,100,1)),
    # Learning rate from exp(-3), exp(0) basically [0.05 to 1]
    'learning_rate': hp.loguniform('learning_rate',-3,0),
    # Using similar loguniform logic as above for alpha and weight
    'reg_alpha': hp.loguniform('reg_alpha',-5,-1),
    'reg_lambda': hp.loguniform('reg_lambda',-6,-1),
    'min_child_weight': hp.loguniform('min_child_weight',-1,3),
    'objective': 'reg:linear',
    'seed':42,
}

best_result = fmin(
    # Pass all of the above to the fmin function which will minimize output to find best method
    fn=objective, # Define the function we created above
    space=search_space, # Pass search space
    algo=tpe.suggest, # Optimization algorithm we are running
    max_evals=50,
    trials=Trials() # Where information of each run is stored
)

# %% [markdown]
# Upon reviewing all of the data in mlflow gui we have found the best run and now want to set the parameters to those of that run.

# %%
params = {
    'learning_rate': 0.09596878839626283,
    'max_depth': 58,
    'min_child_weight': 1.7851046492749176,
    'objective': 'reg:linear',
    'reg_alpha': 0.013442382444691226,
    'reg_lambda': 0.06861630187449783,
    'seed': 42
}

# %%
with mlflow.start_run():
    mlflow.set_tag("model", "xgboost")
    mlflow.log_params(params)
    booster = xgb.train(
        params=params, # Specify parameters which are input variables in this case
        dtrain=train, # Specify training dataset
        num_boost_round=1000, # Set maximum iterations
        evals=[(valid, "validation")], # Specify evaluation dataset
        early_stopping_rounds=50 # If 50 iterations go without improvement early stop is done
    )

# %% [markdown]
# Instead of the above we can actually use auto logging since we are using a supported model (xgboot).
#
# Here are the docs for MLflow auto logging:
#
# https://mlflow.org/docs/latest/tracking/autolog.html

# %%
mlflow.xgboost.autolog()

booster = xgb.train(
    params=params, # Specify parameters which are input variables in this case
    dtrain=train, # Specify training dataset
    num_boost_round=1000, # Set maximum iterations
    evals=[(valid, "validation")], # Specify evaluation dataset
    early_stopping_rounds=50 # If 50 iterations go without improvement early stop is done
)
# Out:
# 2024/05/21 15:20:27 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '37b8891fbd274ec290d80e714d1d948a', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# /home/tsimpson_unix/anaconda3/envs/ml-ops-zoomcamp-01/lib/python3.9/site-packages/xgboost/core.py:160: UserWarning: [15:20:29] WARNING: /workspace/src/objective/regression_obj.cu:209: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# [0]	validation-rmse:11.43418
# [1]	validation-rmse:10.75092
# [2]	validation-rmse:10.15518
# [3]	validation-rmse:9.63778
# [4]	validation-rmse:9.18899
# [5]	validation-rmse:8.80057
# [6]	validation-rmse:8.46494
# [7]	validation-rmse:8.17769
# [8]	validation-rmse:7.93208
# [9]	validation-rmse:7.72328
# [10]	validation-rmse:7.54326
# [11]	validation-rmse:7.39311
# [12]	validation-rmse:7.26053
# [13]	validation-rmse:7.15150
# [14]	validation-rmse:7.05772
# [15]	validation-rmse:6.97641
# [16]	validation-rmse:6.90833
# [17]	validation-rmse:6.84945
# [18]	validation-rmse:6.79777
# [19]	validation-rmse:6.75523
# [20]	validation-rmse:6.71770
# [21]	validation-rmse:6.68500
# [22]	validation-rmse:6.65758
# [23]	validation-rmse:6.63225
# [24]	validation-rmse:6.61071
# [25]	validation-rmse:6.59298
# [26]	validation-rmse:6.57524
# [27]	validation-rmse:6.56109
# [28]	validation-rmse:6.54939
# [29]	validation-rmse:6.53826
# [30]	validation-rmse:6.52740
# [31]	validation-rmse:6.51823
# [32]	validation-rmse:6.51001
# [33]	validation-rmse:6.50223
# [34]	validation-rmse:6.49565
# [35]	validation-rmse:6.49030
# [36]	validation-rmse:6.48408
# [37]	validation-rmse:6.47879
# [38]	validation-rmse:6.47384
# [39]	validation-rmse:6.46901
# [40]	validation-rmse:6.46508
# [41]	validation-rmse:6.46150
# [42]	validation-rmse:6.45855
# [43]	validation-rmse:6.45580
# [44]	validation-rmse:6.45354
# [45]	validation-rmse:6.45149
# [46]	validation-rmse:6.44948
# [47]	validation-rmse:6.44786
# [48]	validation-rmse:6.44607
# [49]	validation-rmse:6.44485
# [50]	validation-rmse:6.44393
# [51]	validation-rmse:6.44214
# [52]	validation-rmse:6.44080
# [53]	validation-rmse:6.43936
# [54]	validation-rmse:6.43870
# [55]	validation-rmse:6.43800
# [56]	validation-rmse:6.43735
# [57]	validation-rmse:6.43678
# [58]	validation-rmse:6.43630
# [59]	validation-rmse:6.43539
# [60]	validation-rmse:6.43426
# [61]	validation-rmse:6.43267
# [62]	validation-rmse:6.43191
# [63]	validation-rmse:6.43088
# [64]	validation-rmse:6.43015
# [65]	validation-rmse:6.42923
# [66]	validation-rmse:6.42795
# [67]	validation-rmse:6.42698
# [68]	validation-rmse:6.42591
# [69]	validation-rmse:6.42541
# [70]	validation-rmse:6.42484
# [71]	validation-rmse:6.42427
# [72]	validation-rmse:6.42330
# [73]	validation-rmse:6.42265
# [74]	validation-rmse:6.42214
# [75]	validation-rmse:6.42096
# [76]	validation-rmse:6.42008
# [77]	validation-rmse:6.41896
# [78]	validation-rmse:6.41792
# [79]	validation-rmse:6.41718
# [80]	validation-rmse:6.41670
# [81]	validation-rmse:6.41600
# [82]	validation-rmse:6.41542
# [83]	validation-rmse:6.41472
# [84]	validation-rmse:6.41406
# [85]	validation-rmse:6.41331
# [86]	validation-rmse:6.41254
# [87]	validation-rmse:6.41198
# [88]	validation-rmse:6.41147
# [89]	validation-rmse:6.41099
# [90]	validation-rmse:6.40994
# [91]	validation-rmse:6.40962
# [92]	validation-rmse:6.40860
# [93]	validation-rmse:6.40809
# [94]	validation-rmse:6.40756
# [95]	validation-rmse:6.40656
# [96]	validation-rmse:6.40597
# [97]	validation-rmse:6.40507
# [98]	validation-rmse:6.40421
# [99]	validation-rmse:6.40296
# [100]	validation-rmse:6.40252
# [101]	validation-rmse:6.40185
# [102]	validation-rmse:6.40113
# [103]	validation-rmse:6.40064
# [104]	validation-rmse:6.40028
# [105]	validation-rmse:6.39974
# [106]	validation-rmse:6.39924
# [107]	validation-rmse:6.39890
# [108]	validation-rmse:6.39842
# [109]	validation-rmse:6.39793
# [110]	validation-rmse:6.39742
# [111]	validation-rmse:6.39702
# [112]	validation-rmse:6.39646
# [113]	validation-rmse:6.39601
# [114]	validation-rmse:6.39561
# [115]	validation-rmse:6.39503
# [116]	validation-rmse:6.39451
# [117]	validation-rmse:6.39388
# [118]	validation-rmse:6.39344
# [119]	validation-rmse:6.39297
# [120]	validation-rmse:6.39264
# [121]	validation-rmse:6.39171
# [122]	validation-rmse:6.39145
# [123]	validation-rmse:6.39055
# [124]	validation-rmse:6.38985
# [125]	validation-rmse:6.38918
# [126]	validation-rmse:6.38856
# [127]	validation-rmse:6.38805
# [128]	validation-rmse:6.38773
# [129]	validation-rmse:6.38705
# [130]	validation-rmse:6.38638
# [131]	validation-rmse:6.38624
# [312]	validation-rmse:6.33852
# [313]	validation-rmse:6.33840
# [314]	validation-rmse:6.33816
# [315]	validation-rmse:6.33804
# [316]	validation-rmse:6.33789
# [317]	validation-rmse:6.33780
# [318]	validation-rmse:6.33771
# [319]	validation-rmse:6.33768
# [320]	validation-rmse:6.33738
# [321]	validation-rmse:6.33733
# [322]	validation-rmse:6.33727
# [323]	validation-rmse:6.33730
# [324]	validation-rmse:6.33728
# [325]	validation-rmse:6.33728
# [326]	validation-rmse:6.33712
# [327]	validation-rmse:6.33706
# [328]	validation-rmse:6.33675
# [329]	validation-rmse:6.33669
# [330]	validation-rmse:6.33638
# [331]	validation-rmse:6.33617
# [332]	validation-rmse:6.33624
# [333]	validation-rmse:6.33608
# [334]	validation-rmse:6.33591
# [335]	validation-rmse:6.33577
# [336]	validation-rmse:6.33555
# [337]	validation-rmse:6.33538
# [338]	validation-rmse:6.33494
# [339]	validation-rmse:6.33483
# [340]	validation-rmse:6.33472
# [341]	validation-rmse:6.33477
# [342]	validation-rmse:6.33481
# [343]	validation-rmse:6.33459
# [344]	validation-rmse:6.33377
# [345]	validation-rmse:6.33335
# [346]	validation-rmse:6.33317
# [347]	validation-rmse:6.33307
# [348]	validation-rmse:6.33298
# [349]	validation-rmse:6.33271
# [350]	validation-rmse:6.33244
# [351]	validation-rmse:6.33239
# [352]	validation-rmse:6.33232
# [353]	validation-rmse:6.33219
# [354]	validation-rmse:6.33213
# [355]	validation-rmse:6.33214
# [356]	validation-rmse:6.33184
# [357]	validation-rmse:6.33167
# [358]	validation-rmse:6.33155
# [359]	validation-rmse:6.33137
# [360]	validation-rmse:6.33124
# [361]	validation-rmse:6.33086
# [362]	validation-rmse:6.33095
# [363]	validation-rmse:6.33082
# [364]	validation-rmse:6.33059
# [365]	validation-rmse:6.33037
# [366]	validation-rmse:6.33044
# [367]	validation-rmse:6.33039
# [368]	validation-rmse:6.33032
# [369]	validation-rmse:6.32986
# [370]	validation-rmse:6.32974
# [371]	validation-rmse:6.32965
# [372]	validation-rmse:6.32962
# [373]	validation-rmse:6.32941
# [374]	validation-rmse:6.32922
# [375]	validation-rmse:6.32885
# [376]	validation-rmse:6.32868
# [377]	validation-rmse:6.32861
# [378]	validation-rmse:6.32860
# [379]	validation-rmse:6.32847
# [380]	validation-rmse:6.32831
# [381]	validation-rmse:6.32826
# [382]	validation-rmse:6.32755
# [383]	validation-rmse:6.32757
# [384]	validation-rmse:6.32763
# [385]	validation-rmse:6.32740
# [386]	validation-rmse:6.32740
# [387]	validation-rmse:6.32718
# [388]	validation-rmse:6.32693
# [389]	validation-rmse:6.32685
# [390]	validation-rmse:6.32684
# [391]	validation-rmse:6.32676
# [392]	validation-rmse:6.32685
# [393]	validation-rmse:6.32677
# [394]	validation-rmse:6.32667
# [395]	validation-rmse:6.32639
# [396]	validation-rmse:6.32643
# [397]	validation-rmse:6.32642
# [398]	validation-rmse:6.32640
# [399]	validation-rmse:6.32629
# [400]	validation-rmse:6.32623
# [401]	validation-rmse:6.32629
# [402]	validation-rmse:6.32605
# [403]	validation-rmse:6.32588
# [404]	validation-rmse:6.32584
# [405]	validation-rmse:6.32552
# [406]	validation-rmse:6.32517
# [407]	validation-rmse:6.32520
# [408]	validation-rmse:6.32457
# [409]	validation-rmse:6.32463
# [410]	validation-rmse:6.32455
# [411]	validation-rmse:6.32436
# [412]	validation-rmse:6.32439
# [413]	validation-rmse:6.32422
# [414]	validation-rmse:6.32408
# [415]	validation-rmse:6.32413
# [416]	validation-rmse:6.32406
# [417]	validation-rmse:6.32392
# [418]	validation-rmse:6.32396
# [419]	validation-rmse:6.32376
# [420]	validation-rmse:6.32370
# [421]	validation-rmse:6.32358
# [422]	validation-rmse:6.32345
# [423]	validation-rmse:6.32330
# [424]	validation-rmse:6.32325
# [425]	validation-rmse:6.32302
# [426]	validation-rmse:6.32303
# [427]	validation-rmse:6.32288
# [428]	validation-rmse:6.32262
# [429]	validation-rmse:6.32272
# [430]	validation-rmse:6.32260
# [431]	validation-rmse:6.32255
# [432]	validation-rmse:6.32249
# [433]	validation-rmse:6.32224
# [434]	validation-rmse:6.32205
# [435]	validation-rmse:6.32215
# [436]	validation-rmse:6.32207
# [437]	validation-rmse:6.32197
# [438]	validation-rmse:6.32164
# [439]	validation-rmse:6.32167
# [440]	validation-rmse:6.32155
# [441]	validation-rmse:6.32149
# [442]	validation-rmse:6.32136
# [443]	validation-rmse:6.32135
# [444]	validation-rmse:6.32125
# [445]	validation-rmse:6.32113
# [446]	validation-rmse:6.32135
# [447]	validation-rmse:6.32129
# [448]	validation-rmse:6.32125
# [449]	validation-rmse:6.32133
# [450]	validation-rmse:6.32126
# [451]	validation-rmse:6.32114
# [452]	validation-rmse:6.32123
# [453]	validation-rmse:6.32114
# [454]	validation-rmse:6.32120
# [455]	validation-rmse:6.32108
# [456]	validation-rmse:6.32100
# [457]	validation-rmse:6.32086
# [458]	validation-rmse:6.32072
# [459]	validation-rmse:6.32056
# [460]	validation-rmse:6.32056
# [461]	validation-rmse:6.32057
# [462]	validation-rmse:6.32055
# [463]	validation-rmse:6.32058
# [464]	validation-rmse:6.32055
# [465]	validation-rmse:6.32054
# [466]	validation-rmse:6.32021
# [467]	validation-rmse:6.32016
# [468]	validation-rmse:6.31994
# [469]	validation-rmse:6.31976
# [470]	validation-rmse:6.31990
# [471]	validation-rmse:6.31942
# [472]	validation-rmse:6.31921
# [473]	validation-rmse:6.31913
# [474]	validation-rmse:6.31902
# [475]	validation-rmse:6.31892
# [476]	validation-rmse:6.31875
# [477]	validation-rmse:6.31867
# [478]	validation-rmse:6.31842
# [479]	validation-rmse:6.31842
# [480]	validation-rmse:6.31842
# [481]	validation-rmse:6.31842
# [482]	validation-rmse:6.31837
# [483]	validation-rmse:6.31831
# [484]	validation-rmse:6.31821
# [485]	validation-rmse:6.31820
# [486]	validation-rmse:6.31804
# [487]	validation-rmse:6.31800
# [488]	validation-rmse:6.31795
# [489]	validation-rmse:6.31781
# [490]	validation-rmse:6.31768
# [491]	validation-rmse:6.31791
# [762]	validation-rmse:6.31023
# [763]	validation-rmse:6.31028
# [764]	validation-rmse:6.31026
# [765]	validation-rmse:6.31033
# [766]	validation-rmse:6.31030
# [767]	validation-rmse:6.31039
# [768]	validation-rmse:6.31032
# [769]	validation-rmse:6.31034
# [770]	validation-rmse:6.31033
# [771]	validation-rmse:6.31026
# [772]	validation-rmse:6.31028
# [773]	validation-rmse:6.31016
# [774]	validation-rmse:6.31012
# [775]	validation-rmse:6.31010
# [776]	validation-rmse:6.31007
# [777]	validation-rmse:6.31010
# [778]	validation-rmse:6.31010
# [779]	validation-rmse:6.31021
# [780]	validation-rmse:6.31026
# [781]	validation-rmse:6.31023
# [782]	validation-rmse:6.31027
# [783]	validation-rmse:6.31032
# [784]	validation-rmse:6.31026
# [785]	validation-rmse:6.31027
# [786]	validation-rmse:6.31026
# [787]	validation-rmse:6.31012
# [788]	validation-rmse:6.31013
# [789]	validation-rmse:6.31003
# [790]	validation-rmse:6.31019
# [791]	validation-rmse:6.31032
# [792]	validation-rmse:6.31032
# [793]	validation-rmse:6.31043
# [794]	validation-rmse:6.31040
# [795]	validation-rmse:6.31039
# [796]	validation-rmse:6.31045
# [797]	validation-rmse:6.31074
# [798]	validation-rmse:6.31064
# [799]	validation-rmse:6.31059
# [800]	validation-rmse:6.31055
# [801]	validation-rmse:6.31064
# [802]	validation-rmse:6.31058
# [803]	validation-rmse:6.31060
# [804]	validation-rmse:6.31061
# [805]	validation-rmse:6.31060
# [806]	validation-rmse:6.31071
# [807]	validation-rmse:6.31074
# 2024/05/21 15:22:01 WARNING mlflow.xgboost: Failed to infer model signature: could not sample data to infer model signature: please ensure that autologging is enabled before constructing the dataset.
# 2024/05/21 15:22:01 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/home/tsimpson_unix/anaconda3/envs/ml-ops-zoomcamp-01/lib/python3.9/site-packages/xgboost/core.py:160: UserWarning: [15:22:01] WARNING: /workspace/src/c_api/c_api.cc:1240: Saving into deprecated binary model format, please consider using `json` or `ubj`. Model format will default to JSON in XGBoost 2.2 if not specified."

# %% [markdown]
# Now you will have 3 metrics and 12 parameters automatically if you check the MLflow GUI.

# %% [markdown]
# Now what about model management?

# %% [markdown]
# This is how we exported the model prior:

# %%
# Since our Linear Regression model performed okay let's export it
with open('../models/lin_reg.bin', 'wb') as f_out:
    pickle.dump((dv, lr), f_out) # Save vectorizer and model

# %% [markdown]
# Here is a way to use MLflow:

# %%
mlflow.xgboost.autolog(disable=True)

with mlflow.start_run():
    
    #using same params as previously
    params = {
        'learning_rate': 0.09596878839626283,
        'max_depth': 58,
        'min_child_weight': 1.7851046492749176,
        'objective': 'reg:linear',
        'reg_alpha': 0.013442382444691226,
        'reg_lambda': 0.06861630187449783,
        'seed': 42
    }
    
    mlflow.log_params(params)

    booster = xgb.train(
        params=params, # Specify parameters which are input variables in this case
        dtrain=train, # Specify training dataset
        num_boost_round=1000, # Set maximum iterations
        evals=[(valid, "validation")], # Specify evaluation dataset
        early_stopping_rounds=50 # If 50 iterations go without improvement early stop is done
    )

    y_pred = booster.predict(valid)
    rmse = mean_squared_error(y_val, y_pred, squared=False)
    mlflow.log_metric("rmse", rmse)

    # Pull out the pre-processing so that it is saved in MLflow model management
    with open("models/preprocessors.b", "wb") as f_out:
        pickle.dump(dv, f_out)
    mlflow.log_artifact("models/preprocessors.b", artifact_path="preprocessor")

    mlflow.xgboost.log_model(booster, artifact_path="w2_models_mlflow")
# Out:
# /home/tsimpson_unix/anaconda3/envs/ml-ops-zoomcamp-01/lib/python3.9/site-packages/xgboost/core.py:160: UserWarning: [07:47:25] WARNING: /workspace/src/objective/regression_obj.cu:209: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# [0]	validation-rmse:11.43418
# [1]	validation-rmse:10.75092
# [2]	validation-rmse:10.15518
# [3]	validation-rmse:9.63778
# [4]	validation-rmse:9.18899
# [5]	validation-rmse:8.80057
# [6]	validation-rmse:8.46494
# [7]	validation-rmse:8.17769
# [8]	validation-rmse:7.93208
# [9]	validation-rmse:7.72328
# [10]	validation-rmse:7.54326
# [11]	validation-rmse:7.39311
# [12]	validation-rmse:7.26053
# [13]	validation-rmse:7.15150
# [14]	validation-rmse:7.05772
# [15]	validation-rmse:6.97641
# [16]	validation-rmse:6.90833
# [17]	validation-rmse:6.84945
# [18]	validation-rmse:6.79777
# [19]	validation-rmse:6.75523
# [20]	validation-rmse:6.71770
# [21]	validation-rmse:6.68500
# [22]	validation-rmse:6.65758
# [23]	validation-rmse:6.63225
# [24]	validation-rmse:6.61071
# [25]	validation-rmse:6.59298
# [26]	validation-rmse:6.57524
# [27]	validation-rmse:6.56109
# [28]	validation-rmse:6.54939
# [29]	validation-rmse:6.53826
# [30]	validation-rmse:6.52740
# [31]	validation-rmse:6.51823
# [32]	validation-rmse:6.51001
# [33]	validation-rmse:6.50223
# [34]	validation-rmse:6.49565
# [35]	validation-rmse:6.49030
# [36]	validation-rmse:6.48408
# [37]	validation-rmse:6.47879
# [38]	validation-rmse:6.47384
# [39]	validation-rmse:6.46901
# [40]	validation-rmse:6.46508
# [41]	validation-rmse:6.46150
# [42]	validation-rmse:6.45855
# [43]	validation-rmse:6.45580
# [44]	validation-rmse:6.45354
# [45]	validation-rmse:6.45149
# [46]	validation-rmse:6.44948
# [47]	validation-rmse:6.44786
# [48]	validation-rmse:6.44607
# [49]	validation-rmse:6.44485
# [50]	validation-rmse:6.44393
# [51]	validation-rmse:6.44214
# [52]	validation-rmse:6.44080
# [53]	validation-rmse:6.43936
# [54]	validation-rmse:6.43870
# [55]	validation-rmse:6.43800
# [56]	validation-rmse:6.43735
# [57]	validation-rmse:6.43678
# [58]	validation-rmse:6.43630
# [59]	validation-rmse:6.43539
# [60]	validation-rmse:6.43426
# [61]	validation-rmse:6.43267
# [62]	validation-rmse:6.43191
# [63]	validation-rmse:6.43088
# [64]	validation-rmse:6.43015
# [65]	validation-rmse:6.42923
# [66]	validation-rmse:6.42795
# [67]	validation-rmse:6.42698
# [68]	validation-rmse:6.42591
# [69]	validation-rmse:6.42541
# [70]	validation-rmse:6.42484
# [71]	validation-rmse:6.42427
# [72]	validation-rmse:6.42330
# [73]	validation-rmse:6.42265
# [74]	validation-rmse:6.42214
# [75]	validation-rmse:6.42096
# [76]	validation-rmse:6.42008
# [77]	validation-rmse:6.41896
# [78]	validation-rmse:6.41792
# [79]	validation-rmse:6.41718
# [80]	validation-rmse:6.41670
# [81]	validation-rmse:6.41600
# [82]	validation-rmse:6.41542
# [83]	validation-rmse:6.41472
# [84]	validation-rmse:6.41406
# [85]	validation-rmse:6.41331
# [86]	validation-rmse:6.41254
# [87]	validation-rmse:6.41198
# [88]	validation-rmse:6.41147
# [89]	validation-rmse:6.41099
# [90]	validation-rmse:6.40994
# [91]	validation-rmse:6.40962
# [92]	validation-rmse:6.40860
# [93]	validation-rmse:6.40809
# [94]	validation-rmse:6.40756
# [95]	validation-rmse:6.40656
# [96]	validation-rmse:6.40597
# [97]	validation-rmse:6.40507
# [98]	validation-rmse:6.40421
# [99]	validation-rmse:6.40296
# [100]	validation-rmse:6.40252
# [281]	validation-rmse:6.34394
# [282]	validation-rmse:6.34377
# [283]	validation-rmse:6.34371
# [284]	validation-rmse:6.34349
# [285]	validation-rmse:6.34341
# [286]	validation-rmse:6.34323
# [287]	validation-rmse:6.34306
# [288]	validation-rmse:6.34281
# [289]	validation-rmse:6.34260
# [290]	validation-rmse:6.34247
# [291]	validation-rmse:6.34232
# [292]	validation-rmse:6.34198
# [293]	validation-rmse:6.34187
# [294]	validation-rmse:6.34158
# [295]	validation-rmse:6.34131
# [296]	validation-rmse:6.34108
# [297]	validation-rmse:6.34097
# [298]	validation-rmse:6.34068
# [299]	validation-rmse:6.34058
# [300]	validation-rmse:6.34051
# [301]	validation-rmse:6.34037
# [302]	validation-rmse:6.34014
# [303]	validation-rmse:6.34015
# [304]	validation-rmse:6.33986
# [305]	validation-rmse:6.33969
# [306]	validation-rmse:6.33938
# [307]	validation-rmse:6.33918
# [308]	validation-rmse:6.33912
# [309]	validation-rmse:6.33906
# [310]	validation-rmse:6.33892
# [311]	validation-rmse:6.33879
# [312]	validation-rmse:6.33852
# [313]	validation-rmse:6.33840
# [314]	validation-rmse:6.33816
# [315]	validation-rmse:6.33804
# [316]	validation-rmse:6.33789
# [317]	validation-rmse:6.33780
# [318]	validation-rmse:6.33771
# [319]	validation-rmse:6.33768
# [320]	validation-rmse:6.33738
# [321]	validation-rmse:6.33733
# [322]	validation-rmse:6.33727
# [323]	validation-rmse:6.33730
# [324]	validation-rmse:6.33728
# [325]	validation-rmse:6.33728
# [326]	validation-rmse:6.33712
# [327]	validation-rmse:6.33706
# [328]	validation-rmse:6.33675
# [329]	validation-rmse:6.33669
# [330]	validation-rmse:6.33638
# [331]	validation-rmse:6.33617
# [332]	validation-rmse:6.33624
# [333]	validation-rmse:6.33608
# [334]	validation-rmse:6.33591
# [335]	validation-rmse:6.33577
# [336]	validation-rmse:6.33555
# [337]	validation-rmse:6.33538
# [338]	validation-rmse:6.33494
# [339]	validation-rmse:6.33483
# [340]	validation-rmse:6.33472
# [341]	validation-rmse:6.33477
# [342]	validation-rmse:6.33481
# [343]	validation-rmse:6.33459
# [344]	validation-rmse:6.33377
# [345]	validation-rmse:6.33335
# [346]	validation-rmse:6.33317
# [347]	validation-rmse:6.33307
# [348]	validation-rmse:6.33298
# [349]	validation-rmse:6.33271
# [350]	validation-rmse:6.33244
# [351]	validation-rmse:6.33239
# [352]	validation-rmse:6.33232
# [353]	validation-rmse:6.33219
# [354]	validation-rmse:6.33213
# [355]	validation-rmse:6.33214
# [356]	validation-rmse:6.33184
# [357]	validation-rmse:6.33167
# [358]	validation-rmse:6.33155
# [359]	validation-rmse:6.33137
# [360]	validation-rmse:6.33124
# [361]	validation-rmse:6.33086
# [362]	validation-rmse:6.33095
# [363]	validation-rmse:6.33082
# [364]	validation-rmse:6.33059
# [365]	validation-rmse:6.33037
# [366]	validation-rmse:6.33044
# [367]	validation-rmse:6.33039
# [368]	validation-rmse:6.33032
# [369]	validation-rmse:6.32986
# [370]	validation-rmse:6.32974
# [371]	validation-rmse:6.32965
# [372]	validation-rmse:6.32962
# [373]	validation-rmse:6.32941
# [374]	validation-rmse:6.32922
# [375]	validation-rmse:6.32885
# [376]	validation-rmse:6.32868
# [377]	validation-rmse:6.32861
# [378]	validation-rmse:6.32860
# [379]	validation-rmse:6.32847
# [380]	validation-rmse:6.32831
# [381]	validation-rmse:6.32826
# [382]	validation-rmse:6.32755
# [383]	validation-rmse:6.32757
# [384]	validation-rmse:6.32763
# [385]	validation-rmse:6.32740
# [386]	validation-rmse:6.32740
# [387]	validation-rmse:6.32718
# [388]	validation-rmse:6.32693
# [389]	validation-rmse:6.32685
# [390]	validation-rmse:6.32684
# [391]	validation-rmse:6.32676
# [392]	validation-rmse:6.32685
# [393]	validation-rmse:6.32677
# [394]	validation-rmse:6.32667
# [395]	validation-rmse:6.32639
# [396]	validation-rmse:6.32643
# [397]	validation-rmse:6.32642
# [398]	validation-rmse:6.32640
# [399]	validation-rmse:6.32629
# [400]	validation-rmse:6.32623
# [401]	validation-rmse:6.32629
# [402]	validation-rmse:6.32605
# [403]	validation-rmse:6.32588
# [404]	validation-rmse:6.32584
# [405]	validation-rmse:6.32552
# [406]	validation-rmse:6.32517
# [407]	validation-rmse:6.32520
# [408]	validation-rmse:6.32457
# [409]	validation-rmse:6.32463
# [410]	validation-rmse:6.32455
# [411]	validation-rmse:6.32436
# [412]	validation-rmse:6.32439
# [413]	validation-rmse:6.32422
# [414]	validation-rmse:6.32408
# [415]	validation-rmse:6.32413
# [416]	validation-rmse:6.32406
# [417]	validation-rmse:6.32392
# [418]	validation-rmse:6.32396
# [419]	validation-rmse:6.32376
# [420]	validation-rmse:6.32370
# [421]	validation-rmse:6.32358
# [422]	validation-rmse:6.32345
# [423]	validation-rmse:6.32330
# [424]	validation-rmse:6.32325
# [425]	validation-rmse:6.32302
# [426]	validation-rmse:6.32303
# [427]	validation-rmse:6.32288
# [428]	validation-rmse:6.32262
# [429]	validation-rmse:6.32272
# [430]	validation-rmse:6.32260
# [431]	validation-rmse:6.32255
# [432]	validation-rmse:6.32249
# [433]	validation-rmse:6.32224
# [434]	validation-rmse:6.32205
# [435]	validation-rmse:6.32215
# [436]	validation-rmse:6.32207
# [437]	validation-rmse:6.32197
# [438]	validation-rmse:6.32164
# [439]	validation-rmse:6.32167
# [440]	validation-rmse:6.32155
# [441]	validation-rmse:6.32149
# [442]	validation-rmse:6.32136
# [443]	validation-rmse:6.32135
# [444]	validation-rmse:6.32125
# [445]	validation-rmse:6.32113
# [446]	validation-rmse:6.32135
# [447]	validation-rmse:6.32129
# [448]	validation-rmse:6.32125
# [449]	validation-rmse:6.32133
# [450]	validation-rmse:6.32126
# [451]	validation-rmse:6.32114
# [452]	validation-rmse:6.32123
# [453]	validation-rmse:6.32114
# [454]	validation-rmse:6.32120
# [455]	validation-rmse:6.32108
# [456]	validation-rmse:6.32100
# [457]	validation-rmse:6.32086
# [458]	validation-rmse:6.32072
# [459]	validation-rmse:6.32056
# [460]	validation-rmse:6.32056
# [731]	validation-rmse:6.31079
# [732]	validation-rmse:6.31087
# [733]	validation-rmse:6.31081
# [734]	validation-rmse:6.31081
# [735]	validation-rmse:6.31087
# [736]	validation-rmse:6.31087
# [737]	validation-rmse:6.31092
# [738]	validation-rmse:6.31100
# [739]	validation-rmse:6.31098
# [740]	validation-rmse:6.31084
# [741]	validation-rmse:6.31044
# [742]	validation-rmse:6.31020
# [743]	validation-rmse:6.31015
# [744]	validation-rmse:6.31012
# [745]	validation-rmse:6.31014
# [746]	validation-rmse:6.31028
# [747]	validation-rmse:6.31028
# [748]	validation-rmse:6.31025
# [749]	validation-rmse:6.31027
# [750]	validation-rmse:6.31008
# [751]	validation-rmse:6.31009
# [752]	validation-rmse:6.31010
# [753]	validation-rmse:6.31003
# [754]	validation-rmse:6.31004
# [755]	validation-rmse:6.30998
# [756]	validation-rmse:6.31001
# [757]	validation-rmse:6.30991
# [758]	validation-rmse:6.31003
# [759]	validation-rmse:6.31025
# [760]	validation-rmse:6.31036
# [761]	validation-rmse:6.31042
# [762]	validation-rmse:6.31023
# [763]	validation-rmse:6.31028
# [764]	validation-rmse:6.31026
# [765]	validation-rmse:6.31033
# [766]	validation-rmse:6.31030
# [767]	validation-rmse:6.31039
# [768]	validation-rmse:6.31032
# [769]	validation-rmse:6.31034
# [770]	validation-rmse:6.31033
# [771]	validation-rmse:6.31026
# [772]	validation-rmse:6.31028
# [773]	validation-rmse:6.31016
# [774]	validation-rmse:6.31012
# [775]	validation-rmse:6.31010
# [776]	validation-rmse:6.31007
# [777]	validation-rmse:6.31010
# [778]	validation-rmse:6.31010
# [779]	validation-rmse:6.31021
# [780]	validation-rmse:6.31026
# [781]	validation-rmse:6.31023
# [782]	validation-rmse:6.31027
# [783]	validation-rmse:6.31032
# [784]	validation-rmse:6.31026
# [785]	validation-rmse:6.31027
# [786]	validation-rmse:6.31026
# [787]	validation-rmse:6.31012
# [788]	validation-rmse:6.31013
# [789]	validation-rmse:6.31003
# [790]	validation-rmse:6.31019
# [791]	validation-rmse:6.31032
# [792]	validation-rmse:6.31032
# [793]	validation-rmse:6.31043
# [794]	validation-rmse:6.31040
# [795]	validation-rmse:6.31039
# [796]	validation-rmse:6.31045
# [797]	validation-rmse:6.31074
# [798]	validation-rmse:6.31064
# [799]	validation-rmse:6.31059
# [800]	validation-rmse:6.31055
# [801]	validation-rmse:6.31064
# [802]	validation-rmse:6.31058
# [803]	validation-rmse:6.31060
# [804]	validation-rmse:6.31061
# [805]	validation-rmse:6.31060
# [806]	validation-rmse:6.31071
# /home/tsimpson_unix/anaconda3/envs/ml-ops-zoomcamp-01/lib/python3.9/site-packages/sklearn/metrics/_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /home/tsimpson_unix/anaconda3/envs/ml-ops-zoomcamp-01/lib/python3.9/site-packages/xgboost/core.py:160: UserWarning: [07:48:25] WARNING: /workspace/src/c_api/c_api.cc:1240: Saving into deprecated binary model format, please consider using `json` or `ubj`. Model format will default to JSON in XGBoost 2.2 if not specified.
#   warnings.warn(smsg, UserWarning)
# /home/tsimpson_unix/anaconda3/envs/ml-ops-zoomcamp-01/lib/python3.9/site-packages/_distutils_hack/__init__.py:11: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils.
#   warnings.warn(
# /home/tsimpson_unix/anaconda3/envs/ml-ops-zoomcamp-01/lib/python3.9/site-packages/_distutils_hack/__init__.py:26: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")

# %% [markdown]
# Now let us try to load a model. Note that I am using the run id from the run above which I grabbed from the MLflow UI.

# %%
#import mlflow
logged_model = 'runs:/6952d3a1ad694b6aa52b72ebfe9c00e1/w2_models_mlflow'

# Load model as PyFuncModel
loaded_model = mlflow.pyfunc.load_model(logged_model)
# Out:
# /home/tsimpson_unix/anaconda3/envs/ml-ops-zoomcamp-01/lib/python3.9/site-packages/xgboost/core.py:160: UserWarning: [07:49:31] WARNING: /workspace/src/objective/regression_obj.cu:209: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)

# %% [markdown]
# By default with this method the model is brought in as a pyfunc as you can see below

# %%
loaded_model
# Out:
# mlflow.pyfunc.loaded_model:
#   artifact_path: w2_models_mlflow
#   flavor: mlflow.xgboost
#   run_id: 6952d3a1ad694b6aa52b72ebfe9c00e1

# %% [markdown]
# It can be converted to an xgboost model as below

# %%
xgboost_model = mlflow.xgboost.load_model(logged_model)
# Out:
# /home/tsimpson_unix/anaconda3/envs/ml-ops-zoomcamp-01/lib/python3.9/site-packages/xgboost/core.py:160: UserWarning: [07:50:41] WARNING: /workspace/src/objective/regression_obj.cu:209: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)

# %% [markdown]
# Now we can make predictions:

# %%
y_pred = xgboost_model.predict(valid)

# %%
y_pred[:10]
# Out:
# array([14.265136 ,  6.9216285, 14.297368 , 24.433304 ,  9.562117 ,
#        17.151281 , 10.5728035,  8.115536 ,  9.29934  , 19.08733  ],
#       dtype=float32)

# %%
# Import packages set client

import mlflow
from mlflow import MlflowClient
from mlflow.entities import ViewType

# IMPORTANT: note the relative path if I just did `sqlite:///mlflow.db` it would create a new MLflow instance not connect to the already made one
MLFLOW_TRACKING_URI = "sqlite:///../mlflow.db"

client = MlflowClient(tracking_uri=MLFLOW_TRACKING_URI)

# %%
# Create an experiment
client.create_experiment(name="experiment-from-notebook")
# Out:
# '2'

# %%
# Show experiment IDs
client.search_experiments()
# Out:
# [<Experiment: artifact_location='/home/tsimpson_unix/ml_ops_zoomcamp/w2_experiment_tracking/notebooks/mlruns/2', creation_time=1716465699169, experiment_id='2', last_update_time=1716465699169, lifecycle_stage='active', name='experiment-from-notebook', tags={}>,
#  <Experiment: artifact_location='/home/tsimpson_unix/ml_ops_zoomcamp/w2_experiment_tracking/mlruns/1', creation_time=1716205390239, experiment_id='1', last_update_time=1716205390239, lifecycle_stage='active', name='nyc-taxi-experiment', tags={}>,
#  <Experiment: artifact_location='mlflow-artifacts:/0', creation_time=1716204842632, experiment_id='0', last_update_time=1716204842632, lifecycle_stage='active', name='Default', tags={}>]

# %%
# Search experiment runs from our previous experiment
runs = client.search_runs(
    experiment_ids="1",
    filter_string="metrics.rmse < 6.5",
    run_view_type=ViewType.ACTIVE_ONLY,
    max_results=10,
    order_by=["metrics.rmse ASC"],
)

# %%
# Show runs
runs
# Out:
# [<Run: data=<RunData: metrics={'rmse': 6.310741579947052}, params={'learning_rate': '0.09596878839626283',
#   'max_depth': '58',
#   'min_child_weight': '1.7851046492749176',
#   'objective': 'reg:linear',
#   'reg_alpha': '0.013442382444691226',
#   'reg_lambda': '0.06861630187449783',
#   'seed': '42'}, tags={'mlflow.log-model.history': '[{"run_id": "6952d3a1ad694b6aa52b72ebfe9c00e1", '
#                               '"artifact_path": "w2_models_mlflow", '
#                               '"utc_time_created": "2024-05-22 '
#                               '11:48:25.606981", "flavors": {"python_function": '
#                               '{"loader_module": "mlflow.xgboost", '
#                               '"python_version": "3.9.19", "data": "model.xgb", '
#                               '"env": {"conda": "conda.yaml", "virtualenv": '
#                               '"python_env.yaml"}}, "xgboost": {"xgb_version": '
#                               '"2.0.3", "data": "model.xgb", "model_class": '
#                               '"xgboost.core.Booster", "model_format": "xgb", '
#                               '"code": null}}, "model_uuid": '
#                               '"3c31d42544374ba9a7262bd4c5fdc95f", '
#                               '"mlflow_version": "2.13.0", "model_size_bytes": '
#                               '14237270}]',
#   'mlflow.runName': 'bouncy-croc-582',
#   'mlflow.source.name': '/home/tsimpson_unix/anaconda3/envs/ml-ops-zoomcamp-01/lib/python3.9/site-packages/ipykernel_launcher.py',
#   'mlflow.source.type': 'LOCAL',
#   'mlflow.user': 'tsimpson_unix'}>, info=<RunInfo: artifact_uri='/home/tsimpson_unix/ml_ops_zoomcamp/w2_experiment_tracking/mlruns/1/6952d3a1ad694b6aa52b72ebfe9c00e1/artifacts', end_time=1716378506595, experiment_id='1', lifecycle_stage='active', run_id='6952d3a1ad694b6aa52b72ebfe9c00e1', run_name='bouncy-croc-582', run_uuid='6952d3a1ad694b6aa52b72ebfe9c00e1', start_time=1716378445017, status='FINISHED', user_id='tsimpson_unix'>, inputs=<RunInputs: dataset_inputs=[]>>,
#  <Run: data=<RunData: metrics={'rmse': 6.310741579947052}, params={'learning_rate': '0.09596878839626283',
#   'max_depth': '58',
#   'min_child_weight': '1.7851046492749176',
#   'objective': 'reg:linear',
#   'reg_alpha': '0.013442382444691226',
#   'reg_lambda': '0.06861630187449783',
#   'seed': '42'}, tags={'mlflow.runName': 'resilient-bear-640',
#   'mlflow.source.name': '/home/tsimpson_unix/anaconda3/envs/ml-ops-zoomcamp-01/lib/python3.9/site-packages/ipykernel_launcher.py',
#   'mlflow.source.type': 'LOCAL',
#   'mlflow.user': 'tsimpson_unix'}>, info=<RunInfo: artifact_uri='/home/tsimpson_unix/ml_ops_zoomcamp/w2_experiment_tracking/mlruns/1/74f269d5586b4f10adc16959bbc0dcdf/artifacts', end_time=1716378365958, experiment_id='1', lifecycle_stage='active', run_id='74f269d5586b4f10adc16959bbc0dcdf', run_name='resilient-bear-640', run_uuid='74f269d5586b4f10adc16959bbc0dcdf', start_time=1716378311579, status='FAILED', user_id='tsimpson_unix'>, inputs=<RunInputs: dataset_inputs=[]>>,
#  <Run: data=<RunData: metrics={'best_iteration': 757.0,
#   'rmse': 6.310741579947052,
#   'stopped_iteration': 807.0,
#   'validation-rmse': 6.309913123769785}, params={'custom_metric': 'None',
#   'early_stopping_rounds': '50',
#   'learning_rate': '0.09596878839626283',
#   'max_depth': '58',
#   'maximize': 'None',
#   'min_child_weight': '1.7851046492749176',
#   'num_boost_round': '1000',
#   'objective': 'reg:linear',
#   'reg_alpha': '0.013442382444691226',
#   'reg_lambda': '0.06861630187449783',
#   'seed': '42',
#   'verbose_eval': 'True'}, tags={'mlflow.log-model.history': '[{"run_id": "2d7b381c344b4038a3dda7f3ce453c40", '
#                               '"artifact_path": "model", "utc_time_created": '
#                               '"2024-05-21 19:40:45.685462", "flavors": '
#                               '{"python_function": {"loader_module": '
#                               '"mlflow.xgboost", "python_version": "3.9.19", '
#                               '"data": "model.xgb", "env": {"conda": '
#                               '"conda.yaml", "virtualenv": "python_env.yaml"}}, '
#                               '"xgboost": {"xgb_version": "2.0.3", "data": '
#                               '"model.xgb", "model_class": '
#                               '"xgboost.core.Booster", "model_format": "xgb", '
#                               '"code": null}}, "model_uuid": '
#                               '"ae477e9601c84f33868f59fe982b796d", '
#                               '"mlflow_version": "2.13.0", "model_size_bytes": '
#                               '14237270}, {"run_id": '
#                               '"2d7b381c344b4038a3dda7f3ce453c40", '
#                               '"artifact_path": "w2_models_mlflow", '
#                               '"utc_time_created": "2024-05-21 '
#                               '19:40:47.624774", "flavors": {"python_function": '
#                               '{"loader_module": "mlflow.xgboost", '
#                               '"python_version": "3.9.19", "data": "model.xgb", '
#                               '"env": {"conda": "conda.yaml", "virtualenv": '
#                               '"python_env.yaml"}}, "xgboost": {"xgb_version": '
#                               '"2.0.3", "data": "model.xgb", "model_class": '
#                               '"xgboost.core.Booster", "model_format": "xgb", '
#                               '"code": null}}, "model_uuid": '
#                               '"7fa4e88f4f6c404abc005c4d64c9bc02", '
#                               '"mlflow_version": "2.13.0", "model_size_bytes": '
#                               '14237270}]',
#   'mlflow.runName': 'selective-dog-497',
#   'mlflow.source.name': '/home/tsimpson_unix/anaconda3/envs/ml-ops-zoomcamp-01/lib/python3.9/site-packages/ipykernel_launcher.py',
#   'mlflow.source.type': 'LOCAL',
#   'mlflow.user': 'tsimpson_unix'}>, info=<RunInfo: artifact_uri='/home/tsimpson_unix/ml_ops_zoomcamp/w2_experiment_tracking/mlruns/1/2d7b381c344b4038a3dda7f3ce453c40/artifacts', end_time=1716320448494, experiment_id='1', lifecycle_stage='active', run_id='2d7b381c344b4038a3dda7f3ce453c40', run_name='selective-dog-497', run_uuid='2d7b381c344b4038a3dda7f3ce453c40', start_time=1716320352411, status='FINISHED', user_id='tsimpson_unix'>, inputs=<RunInputs: dataset_inputs=[<DatasetInput: dataset=<Dataset: digest='4c74e29a', name='dataset', profile=('{"features_shape": [73908, 13221], "features_size": 977137668, '
#   '"features_nbytes": 3908550672}'), schema=('{"mlflow_tensorspec": {"features": "[{\\"type\\": \\"tensor\\", '
#   '\\"tensor-spec\\": {\\"dtype\\": \\"float32\\", \\"shape\\": [-1, '
#   '13221]}}]", "targets": null}}'), source=('{"tags": {"mlflow.user": "tsimpson_unix", "mlflow.source.name": '
#   '"/home/tsimpson_unix/anaconda3/envs/ml-ops-zoomcamp-01/lib/python3.9/site-packages/ipykernel_launcher.py", '
#   '"mlflow.source.type": "LOCAL"}}'), source_type='code'>, tags=[<InputTag: key='mlflow.data.context', value='train'>]>,
#   <DatasetInput: dataset=<Dataset: digest='0f5f0969', name='validation', profile=('{"features_shape": [61921, 13221], "features_size": 818657541, '
#   '"features_nbytes": 3274630164}'), schema=('{"mlflow_tensorspec": {"features": "[{\\"type\\": \\"tensor\\", '
#   '\\"tensor-spec\\": {\\"dtype\\": \\"float32\\", \\"shape\\": [-1, '
#   '13221]}}]", "targets": null}}'), source=('{"tags": {"mlflow.user": "tsimpson_unix", "mlflow.source.name": '
#   '"/home/tsimpson_unix/anaconda3/envs/ml-ops-zoomcamp-01/lib/python3.9/site-packages/ipykernel_launcher.py", '
#   '"mlflow.source.type": "LOCAL"}}'), source_type='code'>, tags=[<InputTag: key='mlflow.data.context', value='eval'>]>]>>,
#  <Run: data=<RunData: metrics={'rmse': 6.310741579947052}, params={'learning_rate': '0.09596878839626283',
#   'max_depth': '58',
#   'min_child_weight': '1.7851046492749176',
#   'objective': 'reg:linear',
#   'reg_alpha': '0.013442382444691226',
#   'reg_lambda': '0.06861630187449783',
#   'seed': '42'}, tags={'mlflow.runName': 'kindly-midge-535',
#   'mlflow.source.name': '/home/tsimpson_unix/anaconda3/envs/ml-ops-zoomcamp-01/lib/python3.9/site-packages/ipykernel_launcher.py',
#   'mlflow.source.type': 'LOCAL',
#   'mlflow.user': 'tsimpson_unix',
#   'model': 'xgboost'}>, info=<RunInfo: artifact_uri='/home/tsimpson_unix/ml_ops_zoomcamp/w2_experiment_tracking/mlruns/1/16f54d4a7cf84cf695aa63bad66dbd81/artifacts', end_time=1716208591181, experiment_id='1', lifecycle_stage='active', run_id='16f54d4a7cf84cf695aa63bad66dbd81', run_name='kindly-midge-535', run_uuid='16f54d4a7cf84cf695aa63bad66dbd81', start_time=1716208535425, status='FINISHED', user_id='tsimpson_unix'>, inputs=<RunInputs: dataset_inputs=[]>>,
#  <Run: data=<RunData: metrics={'rmse': 6.312370085295344}, params={'learning_rate': '0.12523265411329804',
#   'max_depth': '51',
#   'min_child_weight': '1.0982961845871497',
#   'objective': 'reg:linear',
#   'reg_alpha': '0.07479572100024652',
#   'reg_lambda': '0.023518981925873407',
#   'seed': '42'}, tags={'mlflow.runName': 'delicate-stoat-944',
#   'mlflow.source.name': '/home/tsimpson_unix/anaconda3/envs/ml-ops-zoomcamp-01/lib/python3.9/site-packages/ipykernel_launcher.py',
#   'mlflow.source.type': 'LOCAL',
#   'mlflow.user': 'tsimpson_unix',
#   'model': 'xgboost'}>, info=<RunInfo: artifact_uri='/home/tsimpson_unix/ml_ops_zoomcamp/w2_experiment_tracking/mlruns/1/073f3c110c834bf2aaf5290183db08ce/artifacts', end_time=1716207886145, experiment_id='1', lifecycle_stage='active', run_id='073f3c110c834bf2aaf5290183db08ce', run_name='delicate-stoat-944', run_uuid='073f3c110c834bf2aaf5290183db08ce', start_time=1716207842707, status='FINISHED', user_id='tsimpson_unix'>, inputs=<RunInputs: dataset_inputs=[]>>,
#  <Run: data=<RunData: metrics={'rmse': 6.3126751829263865}, params={'learning_rate': '0.12424556941109904',
#   'max_depth': '53',
#   'min_child_weight': '1.9406544010566895',
#   'objective': 'reg:linear',
#   'reg_alpha': '0.1471415037915632',
#   'reg_lambda': '0.02813836182420705',
#   'seed': '42'}, tags={'mlflow.runName': 'gregarious-bug-520',
#   'mlflow.source.name': '/home/tsimpson_unix/anaconda3/envs/ml-ops-zoomcamp-01/lib/python3.9/site-packages/ipykernel_launcher.py',
#   'mlflow.source.type': 'LOCAL',
#   'mlflow.user': 'tsimpson_unix',
#   'model': 'xgboost'}>, info=<RunInfo: artifact_uri='/home/tsimpson_unix/ml_ops_zoomcamp/w2_experiment_tracking/mlruns/1/b9eec68eac544a94a2da0652a2aeb833/artifacts', end_time=1716209570866, experiment_id='1', lifecycle_stage='active', run_id='b9eec68eac544a94a2da0652a2aeb833', run_name='gregarious-bug-520', run_uuid='b9eec68eac544a94a2da0652a2aeb833', start_time=1716209537146, status='FINISHED', user_id='tsimpson_unix'>, inputs=<RunInputs: dataset_inputs=[]>>,
#  <Run: data=<RunData: metrics={'rmse': 6.31321046881417}, params={'learning_rate': '0.15025672563761028',
#   'max_depth': '47',
#   'min_child_weight': '1.5227888617564327',
#   'objective': 'reg:linear',
#   'reg_alpha': '0.015094675009806033',
#   'reg_lambda': '0.0038591966327896285',
#   'seed': '42'}, tags={'mlflow.runName': 'marvelous-rook-587',
#   'mlflow.source.name': '/home/tsimpson_unix/anaconda3/envs/ml-ops-zoomcamp-01/lib/python3.9/site-packages/ipykernel_launcher.py',
#   'mlflow.source.type': 'LOCAL',
#   'mlflow.user': 'tsimpson_unix',
#   'model': 'xgboost'}>, info=<RunInfo: artifact_uri='/home/tsimpson_unix/ml_ops_zoomcamp/w2_experiment_tracking/mlruns/1/f5b0cc00bb5041e2bade12c119b4bf43/artifacts', end_time=1716209343862, experiment_id='1', lifecycle_stage='active', run_id='f5b0cc00bb5041e2bade12c119b4bf43', run_name='marvelous-rook-587', run_uuid='f5b0cc00bb5041e2bade12c119b4bf43', start_time=1716209307926, status='FINISHED', user_id='tsimpson_unix'>, inputs=<RunInputs: dataset_inputs=[]>>,
#  <Run: data=<RunData: metrics={'rmse': 6.315148806926785}, params={'learning_rate': '0.09692132250406352',
#   'max_depth': '60',
#   'min_child_weight': '1.863718114587027',
#   'objective': 'reg:linear',
#   'reg_alpha': '0.0164239526621994',
#   'reg_lambda': '0.069538484976765',
#   'seed': '42'}, tags={'mlflow.runName': 'clean-carp-15',
#   'mlflow.source.name': '/home/tsimpson_unix/anaconda3/envs/ml-ops-zoomcamp-01/lib/python3.9/site-packages/ipykernel_launcher.py',
#   'mlflow.source.type': 'LOCAL',
#   'mlflow.user': 'tsimpson_unix',
#   'model': 'xgboost'}>, info=<RunInfo: artifact_uri='/home/tsimpson_unix/ml_ops_zoomcamp/w2_experiment_tracking/mlruns/1/8776c821c20049ec8118308822b1f6d7/artifacts', end_time=1716208535414, experiment_id='1', lifecycle_stage='active', run_id='8776c821c20049ec8118308822b1f6d7', run_name='clean-carp-15', run_uuid='8776c821c20049ec8118308822b1f6d7', start_time=1716208483283, status='FINISHED', user_id='tsimpson_unix'>, inputs=<RunInputs: dataset_inputs=[]>>,
#  <Run: data=<RunData: metrics={'rmse': 6.320793499241351}, params={'learning_rate': '0.26521661048728845',
#   'max_depth': '18',
#   'min_child_weight': '2.9829513570581416',
#   'objective': 'reg:linear',
#   'reg_alpha': '0.01907072786969978',
#   'reg_lambda': '0.3178233804452192',
#   'seed': '42'}, tags={'mlflow.runName': 'intrigued-roo-143',
#   'mlflow.source.name': '/home/tsimpson_unix/anaconda3/envs/ml-ops-zoomcamp-01/lib/python3.9/site-packages/ipykernel_launcher.py',
#   'mlflow.source.type': 'LOCAL',
#   'mlflow.user': 'tsimpson_unix',
#   'model': 'xgboost'}>, info=<RunInfo: artifact_uri='/home/tsimpson_unix/ml_ops_zoomcamp/w2_experiment_tracking/mlruns/1/8eb08fe1cfcd4ed08657201b99a8ff36/artifacts', end_time=1716208245665, experiment_id='1', lifecycle_stage='active', run_id='8eb08fe1cfcd4ed08657201b99a8ff36', run_name='intrigued-roo-143', run_uuid='8eb08fe1cfcd4ed08657201b99a8ff36', start_time=1716208219036, status='FINISHED', user_id='tsimpson_unix'>, inputs=<RunInputs: dataset_inputs=[]>>,
#  <Run: data=<RunData: metrics={'rmse': 6.324623674490226}, params={'learning_rate': '0.056184729448212484',
#   'max_depth': '41',
#   'min_child_weight': '1.7016390826664387',
#   'objective': 'reg:linear',
#   'reg_alpha': '0.039484527558305366',
#   'reg_lambda': '0.025367816655268167',
#   'seed': '42'}, tags={'mlflow.runName': 'resilient-wolf-562',
#   'mlflow.source.name': '/home/tsimpson_unix/anaconda3/envs/ml-ops-zoomcamp-01/lib/python3.9/site-packages/ipykernel_launcher.py',
#   'mlflow.source.type': 'LOCAL',
#   'mlflow.user': 'tsimpson_unix',
#   'model': 'xgboost'}>, info=<RunInfo: artifact_uri='/home/tsimpson_unix/ml_ops_zoomcamp/w2_experiment_tracking/mlruns/1/86f71500f2d0472d9ed45bf01d89f2be/artifacts', end_time=1716208716456, experiment_id='1', lifecycle_stage='active', run_id='86f71500f2d0472d9ed45bf01d89f2be', run_name='resilient-wolf-562', run_uuid='86f71500f2d0472d9ed45bf01d89f2be', start_time=1716208657276, status='FINISHED', user_id='tsimpson_unix'>, inputs=<RunInputs: dataset_inputs=[]>>]

# %%
# Show runs in an easier to read format
for run in runs:
    print(f"run id: {run.info.run_id}, rmse: {run.data.metrics['rmse']:.4f}")
# Out:
# run id: 6952d3a1ad694b6aa52b72ebfe9c00e1, rmse: 6.3107
# run id: 74f269d5586b4f10adc16959bbc0dcdf, rmse: 6.3107
# run id: 2d7b381c344b4038a3dda7f3ce453c40, rmse: 6.3107
# run id: 16f54d4a7cf84cf695aa63bad66dbd81, rmse: 6.3107
# run id: 073f3c110c834bf2aaf5290183db08ce, rmse: 6.3124
# run id: b9eec68eac544a94a2da0652a2aeb833, rmse: 6.3127
# run id: f5b0cc00bb5041e2bade12c119b4bf43, rmse: 6.3132
# run id: 8776c821c20049ec8118308822b1f6d7, rmse: 6.3151
# run id: 8eb08fe1cfcd4ed08657201b99a8ff36, rmse: 6.3208
# run id: 86f71500f2d0472d9ed45bf01d89f2be, rmse: 6.3246

# %%
# Register a model using the run id

mlflow.set_tracking_uri(MLFLOW_TRACKING_URI)

run_id = "2d7b381c344b4038a3dda7f3ce453c40" # Grabbing run id from previous output
model_uri = f"runs:/{run_id}/model"
mlflow.register_model(model_uri=model_uri, name="nyc-taxi-experiment-notebook")

# Each time this is run a new version will be created of the registered model
# Out:
# Registered model 'nyc-taxi-experiment-notebook' already exists. Creating a new version of this model...
# Created version '4' of model 'nyc-taxi-experiment-notebook'.
# <ModelVersion: aliases=[], creation_timestamp=1716466931964, current_stage='None', description=None, last_updated_timestamp=1716466931964, name='nyc-taxi-experiment-notebook', run_id='2d7b381c344b4038a3dda7f3ce453c40', run_link=None, source='/home/tsimpson_unix/ml_ops_zoomcamp/w2_experiment_tracking/mlruns/1/2d7b381c344b4038a3dda7f3ce453c40/artifacts/model', status='READY', status_message=None, tags={}, user_id=None, version=4>

# %%
# Get model versions and aliases (stages being deprecated)

model_name="nyc-taxi-experiment-notebook"
latest_versions = client.search_model_versions()

for version in latest_versions:
    print(f"version: {version.version}, aliases: {version.aliases}")
# Out:
# version: 4, aliases: []
# version: 3, aliases: []
# version: 2, aliases: []
# version: 1, aliases: []
# version: 2, aliases: []
# version: 1, aliases: []

# %%
# Update model version/description

from datetime import datetime
date = datetime.today().date()
model_version = 4

client.update_model_version(
    name=model_name,
    version=model_version,
    description=f"The model version {model_version} was updated on {date}"
)
# Out:
# <ModelVersion: aliases=[], creation_timestamp=1716466931964, current_stage='None', description='The model version 4 was updated on 2024-05-23', last_updated_timestamp=1716467368965, name='nyc-taxi-experiment-notebook', run_id='2d7b381c344b4038a3dda7f3ce453c40', run_link=None, source='/home/tsimpson_unix/ml_ops_zoomcamp/w2_experiment_tracking/mlruns/1/2d7b381c344b4038a3dda7f3ce453c40/artifacts/model', status='READY', status_message=None, tags={}, user_id=None, version=4>
